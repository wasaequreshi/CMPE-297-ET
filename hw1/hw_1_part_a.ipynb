# %%
# !rm -rf milli_imagenet.zip
# !rm -rf milli_imagenet

# %%
# !gdown --id 1x3BSoqoe76FcWdbagLj6Mx6_2EAJ982g
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1x3BSoqoe76FcWdbagLj6Mx6_2EAJ982g
# To: /content/milli_imagenet.zip
# 92.9MB [00:00, 224MB/s]

# %%
# !unzip milli_imagenet.zip
# Out:
# Archive:  milli_imagenet.zip
#    creating: milli_imagenet/
#    creating: milli_imagenet/test/
#   inflating: milli_imagenet/test/car_2715810931_648aa512c2.jpg
#   inflating: milli_imagenet/test/airplane_148113522_3b0c62dcf1.jpg
#   inflating: milli_imagenet/test/cat_1972050799_f63e09067f.jpg
#   inflating: milli_imagenet/test/dog_411390999_7097d3634b.jpg
#   inflating: milli_imagenet/test/dog_640212967_0d8b02dcdd.jpg
#   inflating: milli_imagenet/test/airplane_2043159074_1b5dabcb37.jpg
#   inflating: milli_imagenet/test/elephant_325999779_18c27f01ba.jpg
#   inflating: milli_imagenet/test/car_1260288332_8f3ec15630.jpg
#   inflating: milli_imagenet/test/dog_492288911_a3c455f54c.jpg
#   inflating: milli_imagenet/test/dog_470186220_7595143e12.jpg
#   inflating: milli_imagenet/test/car_2491565093_3315d56e69.jpg
#   inflating: milli_imagenet/test/dog_65983741_7258b41fd9.jpg
#   inflating: milli_imagenet/test/dog_180300673_180c64d718.jpg
#   inflating: milli_imagenet/test/elephant_87654345673872.jpg
#   inflating: milli_imagenet/test/airplane_129260654_805dfe4c52.jpg
#   inflating: milli_imagenet/test/dog_948952651_ae88267702.jpg
#   inflating: milli_imagenet/test/cat_255186437_b7c6f78b86.jpg
#   inflating: milli_imagenet/test/airplane_468435025_55f4acf9c7.jpg
#   inflating: milli_imagenet/test/dog_426597193_4b2d975bb2.jpg
#   inflating: milli_imagenet/test/cat_129880737_1b8825c034.jpg
#   inflating: milli_imagenet/test/cat_352355242352.jpg
#   inflating: milli_imagenet/test/dog_142236307_9a364b60b4.jpg
#   inflating: milli_imagenet/test/airplane_531326560_e50926d902.jpg
#   inflating: milli_imagenet/test/cat_754108251_f92d09ee98.jpg
#   inflating: milli_imagenet/test/elephant_438111209_c4534165e3.jpg
#   inflating: milli_imagenet/test/airplane_2676695368_9f9b4eae18.jpg
#   inflating: milli_imagenet/test/airplane_2585674156_18aeb07be7.jpg
#   inflating: milli_imagenet/test/elephant_171269338_f51fb85aff.jpg
#   inflating: milli_imagenet/test/cat_5874225_665db258f6.jpg
#   inflating: milli_imagenet/test/car_847154336_f782942022.jpg
#   inflating: milli_imagenet/test/cat_54452243_48ce039967.jpg
#   inflating: milli_imagenet/test/elephant_74313201_05e777ebae.jpg
#   inflating: milli_imagenet/test/airplane_209778573_07a297bc98.jpg
#   inflating: milli_imagenet/test/car_1211593365_544882367c.jpg
#   inflating: milli_imagenet/test/dog_139381434_f44371a96d.jpg
#   inflating: milli_imagenet/test/cat_161285442_8bcc94a3d5.jpg
#   inflating: milli_imagenet/test/dog_427063172_521e9f4719.jpg
#   inflating: milli_imagenet/test/airplane_2073643014_8ecbdbd760.jpg
#   inflating: milli_imagenet/test/car_2252854848_fe478a2c88.jpg
#   inflating: milli_imagenet/test/dog_312709157_843ad502ca.jpg
#   inflating: milli_imagenet/test/elephant_2220993619_7bd7814dde.jpg
#   inflating: milli_imagenet/test/airplane_231269454_708350495a.jpg
#   inflating: milli_imagenet/test/elephant_171247089_59042a2b95.jpg
#   inflating: milli_imagenet/test/car_1306938883_43ac47fb70.jpg
#   inflating: milli_imagenet/test/cat_776126883_5bce88df32.jpg
#   inflating: milli_imagenet/test/elephant_113234587_4cfe62c52b.jpg
#   inflating: milli_imagenet/test/airplane_1038817887_adf7a57848.jpg
#   inflating: milli_imagenet/test/airplane_295656508_3672afa948.jpg
#   inflating: milli_imagenet/test/elephant_151963164_a4e1d06d1a.jpg
#   inflating: milli_imagenet/test/elephant_2211547306_caca11f275.jpg
#   inflating: milli_imagenet/test/dog_1516897105_9551eceb74.jpg
#   inflating: milli_imagenet/test/cat_512411718_da2e0a277d.jpg
#   inflating: milli_imagenet/test/car_2697590827_ffed423ebc.jpg
#   inflating: milli_imagenet/test/airplane_1831671971_c9bef61508.jpg
#   inflating: milli_imagenet/test/dog_689779238_2972f61170.jpg
#   inflating: milli_imagenet/test/cat_1284337059_29aaf74695.jpg
#   inflating: milli_imagenet/test/dog_531463060_2d55403b0d.jpg
#   inflating: milli_imagenet/test/cat_527547399_7f7b3c6157.jpg
#   inflating: milli_imagenet/test/dog_110345287_93f7070cb1.jpg
#   inflating: milli_imagenet/test/airplane_508060193_9c49eb2d91.jpg
#   inflating: milli_imagenet/test/cat_1973340147_e454e8f25f.jpg
#   inflating: milli_imagenet/test/dog_3127747_8b48b6cbb6.jpg
#   inflating: milli_imagenet/test/car_1389914352_58f4d44bd5.jpg
#   inflating: milli_imagenet/test/cat_472715185_8308cc5bce.jpg
#   inflating: milli_imagenet/test/car_2431152745_eecfa49641.jpg
#   inflating: milli_imagenet/test/airplane_2315183009_7a1a42e53d.jpg
#   inflating: milli_imagenet/test/airplane_1386341970_cb2e833d33.jpg
#   inflating: milli_imagenet/test/elephant_171252662_0177a9b8c6.jpg
#   inflating: milli_imagenet/test/car_2222620715_5dcdc8107e.jpg
#   inflating: milli_imagenet/test/elephant_1218753234_017a0cbd49.jpg
#   inflating: milli_imagenet/test/dog_2079401653_7f2c97404e.jpg
#   inflating: milli_imagenet/test/dog_145824251_7dec967dd3.jpg
#   inflating: milli_imagenet/test/airplane_28848637_fb93a8b2d3.jpg
#   inflating: milli_imagenet/test/car_440197400_7ceb205417.jpg
#   inflating: milli_imagenet/test/car_2413834942_907709e5ac.jpg
#   inflating: milli_imagenet/test/elephant_1410735420_63e6f2b22c.jpg
#   inflating: milli_imagenet/test/elephant_171242004_b9c098a9a3.jpg
#   inflating: milli_imagenet/test/cat_2197815717_ebee4547c4.jpg
#   inflating: milli_imagenet/test/dog_426584142_22a2af1a1e.jpg
#   inflating: milli_imagenet/test/cat_433442298_f68577ef8b.jpg
#   inflating: milli_imagenet/test/car_2434443162_df523ce0da.jpg
#   inflating: milli_imagenet/test/cat_437815840_ac74ca2be7.jpg
#   inflating: milli_imagenet/test/car_318219179_be7df590f7.jpg
#   inflating: milli_imagenet/test/elephant_148655933_d5a0429b71.jpg
#   inflating: milli_imagenet/test/car_2580085600_5e0cd8aba0.jpg
#   inflating: milli_imagenet/test/cat_1010884970_1aa4af4701.jpg
#   inflating: milli_imagenet/test/car_2287386733_ae621a7abe.jpg
#   inflating: milli_imagenet/test/cat_347227923_11052bff23.jpg
#   inflating: milli_imagenet/test/car_2307489487_1174478b88.jpg
#   inflating: milli_imagenet/test/cat_899083296_736d18ae4b.jpg
#   inflating: milli_imagenet/test/cat_1484611144_d589752ffe.jpg
#   inflating: milli_imagenet/test/airplane_2238500615_0331fa9a26.jpg
#   inflating: milli_imagenet/test/elephant_1608629679_f888063a0f.jpg
#   inflating: milli_imagenet/test/airplane_108887665_86a1047ae4.jpg
#   inflating: milli_imagenet/test/car_2586480449_a32cce2373.jpg
#   inflating: milli_imagenet/test/car_2381133853_baa778028d.jpg
#   inflating: milli_imagenet/test/cat_135579916_ce5bd90475.jpg
#   inflating: milli_imagenet/test/elephant_511505250_3139785b47.jpg
#   inflating: milli_imagenet/test/car_90623098_7730e7e18e.jpg
#   inflating: milli_imagenet/test/cat_2156521163_f7d45b6f6e.jpg
#   inflating: milli_imagenet/test/cat_798503612_b64cc21817.jpg
#   inflating: milli_imagenet/test/airplane_432296669_8e70269a64.jpg
#   inflating: milli_imagenet/test/cat_461692455_5ca4596359.jpg
#   inflating: milli_imagenet/test/airplane_1203776763_cc136816f4.jpg
#   inflating: milli_imagenet/test/car_2735375964_9226b2ea80.jpg
#   inflating: milli_imagenet/test/car_2514077768_74511f44e0.jpg
#   inflating: milli_imagenet/test/airplane_198836419_7715868a15.jpg
#   inflating: milli_imagenet/test/airplane_2536232265_b8bfed0ac8.jpg
#   inflating: milli_imagenet/test/airplane_2247971672_09ee26e459.jpg
#   inflating: milli_imagenet/test/car_1410830620_2efe7370c2.jpg
#   inflating: milli_imagenet/test/cat_461691100_5b9d9b1fea.jpg
#   inflating: milli_imagenet/test/cat_2215772954_e90cf8cd88.jpg
#   inflating: milli_imagenet/test/elephant_485991491_17a7885564.jpg
#   inflating: milli_imagenet/test/elephant_1355838972_09ca54a84a.jpg
#   inflating: milli_imagenet/test/elephant_86753692_1770f441d3.jpg
#   inflating: milli_imagenet/test/airplane_2734097830_603caa0767.jpg
#   inflating: milli_imagenet/test/dog_355633623_dbace3e0c3.jpg
#   inflating: milli_imagenet/test/car_2106429850_fb885a1abd.jpg
#   inflating: milli_imagenet/test/elephant_311928137_0e3b2cadf5.jpg
#   inflating: milli_imagenet/test/dog_312128999_538a288fb5.jpg
#   inflating: milli_imagenet/test/car_2405552020_ee3df8170e.jpg
#   inflating: milli_imagenet/test/elephant_290934359_df434fea07.jpg
#   inflating: milli_imagenet/test/elephant_1512248794_a732f0d77c.jpg
#   inflating: milli_imagenet/test/airplane_548896275_db0585f740.jpg
#   inflating: milli_imagenet/test/cat_468615076_a2450bf20b.jpg
#   inflating: milli_imagenet/test/elephant_2191773107_7d1853fcf2.jpg
#   inflating: milli_imagenet/test/cat_1287089510_f5569fdd22.jpg
#   inflating: milli_imagenet/test/airplane_2485485020_55f5f2ab3a.jpg
#   inflating: milli_imagenet/test/dog_2039628037_5e273b0c20.jpg
#   inflating: milli_imagenet/test/elephant_257264886_d95791f5e7.jpg
#   inflating: milli_imagenet/test/elephant_382853939_24ef96c69e.jpg
#   inflating: milli_imagenet/test/elephant_173044982_fd1a0e389d.jpg
#   inflating: milli_imagenet/test/airplane_2558435594_eb496300aa.jpg
#   inflating: milli_imagenet/test/airplane_2670805281_ec2ce38c9f.jpg
#   inflating: milli_imagenet/test/dog_366070882_1419a396aa.jpg
#   inflating: milli_imagenet/test/car_534980886_bad9a81cc9.jpg
#   inflating: milli_imagenet/test/elephant_99995471_546ba6222b.jpg
#   inflating: milli_imagenet/test/dog_1083277185_895b3462ac.jpg
#   inflating: milli_imagenet/test/cat_310343121_dc734b21fa.jpg
#   inflating: milli_imagenet/test/elephant_541037016_ecfa6df5e5.jpg
#   inflating: milli_imagenet/test/dog_1412971589_b12e881204.jpg
#   inflating: milli_imagenet/test/elephant_529299460_829382d065.jpg
#   inflating: milli_imagenet/test/dog_142225146_a6fd6f811f.jpg
#   inflating: milli_imagenet/test/airplane_2455319970_3353b0b541.jpg
#   inflating: milli_imagenet/test/dog_406630010_dfdcd4221e.jpg
#   inflating: milli_imagenet/test/car_2254848065_6c119575bd.jpg
#   inflating: milli_imagenet/test/elephant_1095153437_a6fb001195.jpg
#   inflating: milli_imagenet/test/cat_898500300_8cc2a6a0c2.jpg
#   inflating: milli_imagenet/test/car_45260804_1cdb221452.jpg
#   inflating: milli_imagenet/test/airplane_49072253_d7c099be66.jpg
#   inflating: milli_imagenet/test/elephant_330285980_d7eeca818d.jpg
#   inflating: milli_imagenet/test/dog_24892618_e8f5b26ccb.jpg
#   inflating: milli_imagenet/test/cat_1224559581_c3c3464cca.jpg
#   inflating: milli_imagenet/test/airplane_525299872_15866f6ee8.jpg
#   inflating: milli_imagenet/test/car_2549993855_dbe4530875.jpg
#   inflating: milli_imagenet/test/cat_2095245869_167f4df935.jpg
#   inflating: milli_imagenet/test/dog_1114867042_00a54edba3.jpg
#   inflating: milli_imagenet/test/elephant_67028545_4df7a600ce.jpg
#   inflating: milli_imagenet/test/car_2648659865_8672193d07.jpg
#   inflating: milli_imagenet/test/dog_86291932_58fc26530a.jpg
#   inflating: milli_imagenet/test/car_2694724051_6838b26d06.jpg
#   inflating: milli_imagenet/test/car_172748956_13f0ab104f.jpg
#   inflating: milli_imagenet/test/car_2492389532_9a2afb453a.jpg
#   inflating: milli_imagenet/test/dog_1890689502_00198c6bd1.jpg
#   inflating: milli_imagenet/test/elephant_164321329_eecf2ca755.jpg
#   inflating: milli_imagenet/test/airplane_2043177578_681270a538.jpg
#   inflating: milli_imagenet/test/car_1576721872_a436b35dce.jpg
#   inflating: milli_imagenet/test/car_2708631349_52689879b0.jpg
#   inflating: milli_imagenet/test/elephant_11543351_3c9cca11b0.jpg
#   inflating: milli_imagenet/test/test.json
#   inflating: milli_imagenet/test/elephant_2141104611_56c21c113f.jpg
#   inflating: milli_imagenet/test/car_2431313043_0726effd05.jpg
#   inflating: milli_imagenet/test/elephant_32614226_c0d069aff3.jpg
#   inflating: milli_imagenet/test/dog_406808925_239a383ee7.jpg
#   inflating: milli_imagenet/test/car_447282920_103e199bd8.jpg
#   inflating: milli_imagenet/test/dog_1460011399_85bf054ef1.jpg
#   inflating: milli_imagenet/test/elephant_1238594110_02b42477aa.jpg
#   inflating: milli_imagenet/test/airplane_2040809891_f399741467.jpg
#   inflating: milli_imagenet/test/dog_426965780_d9066d8d5e.jpg
#   inflating: milli_imagenet/test/car_2615671272_b620115fec.jpg
#   inflating: milli_imagenet/test/cat_1778591983_01e18958fc.jpg
#   inflating: milli_imagenet/test/car_2483967922_e1c95dd28e.jpg
#   inflating: milli_imagenet/test/cat_964126791_6f40ca5177.jpg
#   inflating: milli_imagenet/test/cat_1210503252_5383fe1c12.jpg
#   inflating: milli_imagenet/test/airplane_2165866735_d939404353.jpg
#   inflating: milli_imagenet/test/car_2373896064_3acf6117fa.jpg
#   inflating: milli_imagenet/test/dog_180300665_18803acdb9.jpg
#   inflating: milli_imagenet/test/cat_1484751958_b16fedd4c2.jpg
#   inflating: milli_imagenet/test/cat_807828373_291a605452.jpg
#   inflating: milli_imagenet/test/dog_1297270939_c8bf51c1b1.jpg
#   inflating: milli_imagenet/test/dog_178634525_3e34d4e572.jpg
#   inflating: milli_imagenet/test/airplane_995968008_74475dee27.jpg
#   inflating: milli_imagenet/test/car_1389196489_232f7351b5.jpg
#   inflating: milli_imagenet/test/cat_439881434_c4d255c21c.jpg
#   inflating: milli_imagenet/test/airplane_389068663_68b8cef101.jpg
#   inflating: milli_imagenet/test/airplane_2321651122_6c0f09d96a.jpg
#   inflating: milli_imagenet/test/airplane_2405986584_ef95c7c2fc.jpg
#   inflating: milli_imagenet/test/car_2210892922_900a07f40c.jpg
#   inflating: milli_imagenet/test/elephant_171267834_b13b56a83b.jpg
#   inflating: milli_imagenet/test/cat_1985731136_84840fcf96.jpg
#   inflating: milli_imagenet/test/cat_157662884_8e2d1dd295.jpg
#   inflating: milli_imagenet/test/elephant_212353461_c1f252fdd3.jpg
#   inflating: milli_imagenet/test/airplane_1584812375_c61879c676.jpg
#   inflating: milli_imagenet/test/airplane_156117114_a849d1a6b5.jpg
#   inflating: milli_imagenet/test/car_2428576787_6658c61000.jpg
#   inflating: milli_imagenet/test/cat_37426080_30edeaf019.jpg
#   inflating: milli_imagenet/test/dog_436013847_c9749a1264.jpg
#   inflating: milli_imagenet/test/car_2252853368_aca02d46ac.jpg
#   inflating: milli_imagenet/test/airplane_2885315_db5dd13d26.jpg
#   inflating: milli_imagenet/test/dog_2126832940_9d36698813.jpg
#   inflating: milli_imagenet/test/dog_437176079_947526e681.jpg
#   inflating: milli_imagenet/test/airplane_2576984819_daa8e59e75.jpg
#   inflating: milli_imagenet/test/elephant_518072244_2b96a023a6.jpg
#   inflating: milli_imagenet/test/cat_1737181061_d4391a9627.jpg
#   inflating: milli_imagenet/test/dog_431241943_809206eedb.jpg
#   inflating: milli_imagenet/test/dog_2141649454_4a04307194.jpg
#   inflating: milli_imagenet/test/airplane_661682258_52d55b9cf5.jpg
#   inflating: milli_imagenet/test/elephant_273917192_56fc529b5a.jpg
#   inflating: milli_imagenet/test/dog_410102108_ba3b4ead0a.jpg
#   inflating: milli_imagenet/test/car_2667096806_0d41ea9338.jpg
#   inflating: milli_imagenet/test/cat_459964307_3cb4821ce9.jpg
#   inflating: milli_imagenet/test/airplane_2394014210_0c2679f0b3.jpg
#   inflating: milli_imagenet/test/dog_104993381_ab5f7b8090.jpg
#   inflating: milli_imagenet/test/elephant_99995533_59a7784f09.jpg
#   inflating: milli_imagenet/test/dog_2090987318_31b245a26b.jpg
#   inflating: milli_imagenet/test/car_2513290185_66c46228bc.jpg
#   inflating: milli_imagenet/test/airplane_356218681_4174483173.jpg
#   inflating: milli_imagenet/test/cat_529305169_90b3031371.jpg
#   inflating: milli_imagenet/test/airplane_26176200_25bd110677.jpg
#   inflating: milli_imagenet/test/car_2470019607_20dca68cb4.jpg
#   inflating: milli_imagenet/test/airplane_2334025078_6c07362507.jpg
#   inflating: milli_imagenet/test/dog_312152610_94f33a8507.jpg
#   inflating: milli_imagenet/test/cat_371068422_47a9b29455.jpg
#   inflating: milli_imagenet/test/dog_257226664_89781f6879.jpg
#   inflating: milli_imagenet/test/cat_516293432_b3624910b4.jpg
#   inflating: milli_imagenet/test/elephant_543215461_c0496c4ba6.jpg
#   inflating: milli_imagenet/test/cat_198519299_10c276b8fa.jpg
#   inflating: milli_imagenet/test/dog_440296570_8728a9bfd5.jpg
#   inflating: milli_imagenet/test/elephant_641243299_4a58ecf802.jpg
#   inflating: milli_imagenet/test/dog_119613880_4356e931e5.jpg
#   inflating: milli_imagenet/test/airplane_1386344436_12e9f5769b.jpg
#   inflating: milli_imagenet/test/car_2577908327_83be663bce.jpg
#   inflating: milli_imagenet/test/elephant_1393923408_0223746cb5.jpg
#   inflating: milli_imagenet/test/cat_502335523_a27cc49840.jpg
#   inflating: milli_imagenet/test/elephant_444085033_c4fe2dc8c4.jpg
#   inflating: milli_imagenet/test/cat_126564047_b929724c89.jpg
#   inflating: milli_imagenet/test/car_2501184817_e83512020b.jpg
#   inflating: milli_imagenet/test/elephant_171268376_90d5ca25e9.jpg
#   inflating: milli_imagenet/test/elephant_1585198585_032c6af030.jpg
#   inflating: milli_imagenet/test/airplane_66127344_96a3ee7a6e.jpg
#   inflating: milli_imagenet/test/elephant_171263686_1a9a034aa6.jpg
#    creating: milli_imagenet/train/
#   inflating: milli_imagenet/train/airplane_1304308103_4c33f985e3.jpg
#   inflating: milli_imagenet/train/cat_1561238993_514ec89dc2.jpg
#   inflating: milli_imagenet/train/car_2060051647_508ac196b5.jpg
#   inflating: milli_imagenet/train/cat_63785988_c16c10b4e5.jpg
#   inflating: milli_imagenet/train/car_2336002936_bc0f143705.jpg
#   inflating: milli_imagenet/train/airplane_155943019_6d598183c2.jpg
#   inflating: milli_imagenet/train/car_2183294396_e437a4f162.jpg
#   inflating: milli_imagenet/train/airplane_108805442_29df98caae.jpg
#   inflating: milli_imagenet/train/dog_857507387_6824205ba9.jpg
#   inflating: milli_imagenet/train/elephant_1185858184_d592cc2f82.jpg
#   inflating: milli_imagenet/train/airplane_2321952758_bd792e5156.jpg
#   inflating: milli_imagenet/train/cat_1916815270_9dbc30fa42.jpg
#   inflating: milli_imagenet/train/cat_533444142_ca081fa036.jpg
#   inflating: milli_imagenet/train/cat_337595941_ef58f6fbef.jpg
#   inflating: milli_imagenet/train/airplane_1787934457_c535e16466.jpg
#   inflating: milli_imagenet/train/cat_495308681_e317861b3e.jpg
#   inflating: milli_imagenet/train/car_2350300496_73ca440155.jpg
#   inflating: milli_imagenet/train/airplane_1096362699_813de4c2e6.jpg
#   inflating: milli_imagenet/train/airplane_474620305_d59920b0a4.jpg
#   inflating: milli_imagenet/train/car_977074978_23dc5a4037.jpg
#   inflating: milli_imagenet/train/car_1719233384_e4a9d0116b.jpg
#   inflating: milli_imagenet/train/elephant_1511472618_45b89736e8.jpg
#   inflating: milli_imagenet/train/airplane_2275808698_8d5c84e679.jpg
#   inflating: milli_imagenet/train/cat_202726676_a0796b23bd.jpg
#   inflating: milli_imagenet/train/dog_477040221_c1a354a958.jpg
#   inflating: milli_imagenet/train/cat_289296107_632cde21c3.jpg
#   inflating: milli_imagenet/train/elephant_1022044420_8470e1dba4.jpg
#   inflating: milli_imagenet/train/elephant_1164041552_9609a563b8.jpg
#   inflating: milli_imagenet/train/cat_797614305_bec61c42af.jpg
#   inflating: milli_imagenet/train/airplane_1975832735_f717f3ec9a.jpg
#   inflating: milli_imagenet/train/airplane_118280927_e226078ae6.jpg
#   inflating: milli_imagenet/train/elephant_171241526_de2150f4ce.jpg
#   inflating: milli_imagenet/train/cat_203513295_3a2d83bbc1.jpg
#   inflating: milli_imagenet/train/elephant_1585201543_1d5955ffa6.jpg
#   inflating: milli_imagenet/train/car_194742400_81e8965c25.jpg
#   inflating: milli_imagenet/train/cat_616118242_5025ef5f0d.jpg
#   inflating: milli_imagenet/train/dog_421788808_9f5b98aa32.jpg
#   inflating: milli_imagenet/train/dog_1876898910_8c619d7f76.jpg
#   inflating: milli_imagenet/train/cat_2231206003_461ba2b7b9.jpg
#   inflating: milli_imagenet/train/dog_517654963_f91cb9d05f.jpg
#   inflating: milli_imagenet/train/dog_24600675_d514c279f6.jpg
#   inflating: milli_imagenet/train/car_2476598462_f5a95c12e4.jpg
#   inflating: milli_imagenet/train/car_465826793_cef139ecd4.jpg
#   inflating: milli_imagenet/train/airplane_2105724064_43974b0c4f.jpg
#   inflating: milli_imagenet/train/car_2061050868_f7b7587748.jpg
#   inflating: milli_imagenet/train/cat_597159250_7c93b93b2f.jpg
#   inflating: milli_imagenet/train/car_285526431_0841339810.jpg
#   inflating: milli_imagenet/train/airplane_131661659_8a336a7d72.jpg
#   inflating: milli_imagenet/train/airplane_2451405959_0365255b5e.jpg
#   inflating: milli_imagenet/train/cat_567276998_81dbee8ec0.jpg
#   inflating: milli_imagenet/train/car_2660606120_b6c334c61d.jpg
#   inflating: milli_imagenet/train/car_2492386918_c076dd955e.jpg
#   inflating: milli_imagenet/train/dog_1273840272_701b1e5b48.jpg
#   inflating: milli_imagenet/train/cat_288847186_f720ea4e1e.jpg
#   inflating: milli_imagenet/train/dog_1356436810_e58eefa640.jpg
#   inflating: milli_imagenet/train/elephant_230802412_f44d9faa43.jpg
#   inflating: milli_imagenet/train/cat_108142591_b71035a34c.jpg
#   inflating: milli_imagenet/train/elephant_173174909_49001cfc0c.jpg
#   inflating: milli_imagenet/train/elephant_543112256_1cf60dc0e4.jpg
#   inflating: milli_imagenet/train/airplane_150620537_216a7d8855.jpg
#   inflating: milli_imagenet/train/car_2589199493_fca6f32109.jpg
#   inflating: milli_imagenet/train/dog_2097518451_4256b1389d.jpg
#   inflating: milli_imagenet/train/elephant_1919497998_3ca0e4b024.jpg
#   inflating: milli_imagenet/train/car_2599332519_a6616cdf16.jpg
#   inflating: milli_imagenet/train/car_2351420346_23c219eab5.jpg
#   inflating: milli_imagenet/train/dog_1181925767_d052d9564c.jpg
#   inflating: milli_imagenet/train/dog_312732997_5b100ce2a6.jpg
#   inflating: milli_imagenet/train/car_2458972976_50de894f75.jpg
#   inflating: milli_imagenet/train/cat_92019032_a4a5367bb8.jpg
#   inflating: milli_imagenet/train/airplane_417566632_d7dd01a2e2.jpg
#   inflating: milli_imagenet/train/elephant_688293272_ceadbad172.jpg
#   inflating: milli_imagenet/train/elephant_2222909481_4495bc258d.jpg
#   inflating: milli_imagenet/train/elephant_86751520_246de2a54e.jpg
#   inflating: milli_imagenet/train/elephant_1627247115_8cf8ec21f2.jpg
#   inflating: milli_imagenet/train/cat_2048137462_dcaa3cd495.jpg
#   inflating: milli_imagenet/train/dog_426581883_fb4d65a518.jpg
#   inflating: milli_imagenet/train/elephant_41688469_cd0666aa15.jpg
#   inflating: milli_imagenet/train/cat_1095944283_17208c8595.jpg
#   inflating: milli_imagenet/train/airplane_489765227_0dd28b9dc8.jpg
#   inflating: milli_imagenet/train/cat_2093468793_482e44c1db.jpg
#   inflating: milli_imagenet/train/dog_1387352888_d3d644abb7.jpg
#   inflating: milli_imagenet/train/dog_387243621_1896b84685.jpg
#   inflating: milli_imagenet/train/airplane_976461656_8b0c45b545.jpg
#   inflating: milli_imagenet/train/dog_239570696_ae9feffabd.jpg
#   inflating: milli_imagenet/train/car_2505784372_a752643112.jpg
#   inflating: milli_imagenet/train/elephant_1176787940_266553d518.jpg
#   inflating: milli_imagenet/train/car_2097258855_0f1b7811e9.jpg
#   inflating: milli_imagenet/train/car_2666463976_54eedf3bb0.jpg
#   inflating: milli_imagenet/train/dog_436075642_fbb32aee5c.jpg
#   inflating: milli_imagenet/train/elephant_246315570_7a42cf3a17.jpg
#   inflating: milli_imagenet/train/airplane_465564219_94a9a4f352.jpg
#   inflating: milli_imagenet/train/elephant_414372568_237a948a73.jpg
#   inflating: milli_imagenet/train/elephant_473576678_72879ec91a.jpg
#   inflating: milli_imagenet/train/airplane_178657486_33874a6615.jpg
#   inflating: milli_imagenet/train/cat_495300082_3154ca61aa.jpg
#   inflating: milli_imagenet/train/cat_1140760871_35351b03c5.jpg
#   inflating: milli_imagenet/train/airplane_234092124_c35aa06adb.jpg
#   inflating: milli_imagenet/train/elephant_311927502_8b8aa10080.jpg
#   inflating: milli_imagenet/train/cat_2126527211_599c9725d1.jpg
#   inflating: milli_imagenet/train/airplane_2407329084_cf85f2888d.jpg
#   inflating: milli_imagenet/train/elephant_385865937_33c03eb3e9.jpg
#   inflating: milli_imagenet/train/car_2246277273_574485f09f.jpg
#   inflating: milli_imagenet/train/dog_421707961_f5c41d577e.jpg
#   inflating: milli_imagenet/train/elephant_226299021_95e73d0302.jpg
#   inflating: milli_imagenet/train/airplane_2624048094_4ee7c9c656.jpg
#   inflating: milli_imagenet/train/airplane_1421491245_f2ffce1d75.jpg
#   inflating: milli_imagenet/train/car_2695534564_7c92c64507.jpg
#   inflating: milli_imagenet/train/airplane_6734386_57afa9b156.jpg
#   inflating: milli_imagenet/train/elephant_1379461791_b63821bbfd.jpg
#   inflating: milli_imagenet/train/cat_762884983_4b9e9f53c3.jpg
#   inflating: milli_imagenet/train/airplane_14945087_6dabf38c03.jpg
#   inflating: milli_imagenet/train/car_2615594064_1458efa154.jpg
#   inflating: milli_imagenet/train/elephant_456667815_0fb8872ca6.jpg
#   inflating: milli_imagenet/train/airplane_952270951_c08906c1ae.jpg
#   inflating: milli_imagenet/train/car_2586427847_be81a6ff77.jpg
#   inflating: milli_imagenet/train/dog_8814614_832648ff86.jpg
#   inflating: milli_imagenet/train/elephant_2178210962_0cdff15630.jpg
#   inflating: milli_imagenet/train/dog_406700170_d931d7e3ee.jpg
#   inflating: milli_imagenet/train/dog_2042955483_e186f3bb88.jpg
#   inflating: milli_imagenet/train/airplane_273341574_86ca6a4eac.jpg
#   inflating: milli_imagenet/train/dog_18607259_f348767a35.jpg
#   inflating: milli_imagenet/train/elephant_354730688_b3358aee7e.jpg
#   inflating: milli_imagenet/train/car_2661792958_43aa420d30.jpg
#   inflating: milli_imagenet/train/dog_465166701_d2ec8b8fab.jpg
#   inflating: milli_imagenet/train/elephant_1023104513_7cfc3ed0e4.jpg
#   inflating: milli_imagenet/train/car_1098694903_ff0d9acf87.jpg
#   inflating: milli_imagenet/train/car_2630841172_1713a4148c.jpg
#   inflating: milli_imagenet/train/car_2574168252_16056491dd.jpg
#   inflating: milli_imagenet/train/elephant_548776958_82fdc8d1ff.jpg
#   inflating: milli_imagenet/train/airplane_2352239245_c977d048fb.jpg
#   inflating: milli_imagenet/train/elephant_265651807_1518d1d9eb.jpg
#   inflating: milli_imagenet/train/elephant_543114850_fad8da2728.jpg
#   inflating: milli_imagenet/train/elephant_288773945_0fad95d3e2.jpg
#   inflating: milli_imagenet/train/car_2580618320_7ae76cceb6.jpg
#   inflating: milli_imagenet/train/airplane_2521464028_536706ed07.jpg
#   inflating: milli_imagenet/train/dog_450406665_1068cb8f95.jpg
#   inflating: milli_imagenet/train/elephant_430121468_ae609fb14d.jpg
#   inflating: milli_imagenet/train/elephant_543218189_dcefb1a310.jpg
#   inflating: milli_imagenet/train/airplane_2545180499_f91182afd9.jpg
#   inflating: milli_imagenet/train/elephant_2235050913_4d718b41c7.jpg
#   inflating: milli_imagenet/train/car_432645478_aafd3c6eba.jpg
#   inflating: milli_imagenet/train/elephant_171250362_0dbdfb9c43.jpg
#   inflating: milli_imagenet/train/airplane_326997094_e555d58b1b.jpg
#   inflating: milli_imagenet/train/elephant_311927969_ce0b206db1.jpg
#   inflating: milli_imagenet/train/car_2572249513_ba76b2b8e6.jpg
#   inflating: milli_imagenet/train/cat_464759752_9c09d289fe.jpg
#   inflating: milli_imagenet/train/cat_174732335_7275892317.jpg
#   inflating: milli_imagenet/train/cat_238200853_ab3516a271.jpg
#   inflating: milli_imagenet/train/airplane_2281353209_fbf12be250.jpg
#   inflating: milli_imagenet/train/airplane_2469629787_44829ae0e6.jpg
#   inflating: milli_imagenet/train/car_2440967370_aa0b604017.jpg
#   inflating: milli_imagenet/train/dog_426614274_d356863551.jpg
#   inflating: milli_imagenet/train/car_2724817222_5bcb0219ff.jpg
#   inflating: milli_imagenet/train/elephant_1799470346_21cd2f0d26.jpg
#   inflating: milli_imagenet/train/cat_1041842900_1c5202b05c.jpg
#   inflating: milli_imagenet/train/airplane_2455044316_7a60dc6bfc.jpg
#   inflating: milli_imagenet/train/cat_527070993_77c53e3222.jpg
#   inflating: milli_imagenet/train/airplane_1597746275_af78bbc4c8.jpg
#   inflating: milli_imagenet/train/airplane_138383969_d4887f4344.jpg
#   inflating: milli_imagenet/train/car_2060326215_d0289b872e.jpg
#   inflating: milli_imagenet/train/elephant_231279467_386176e63f.jpg
#   inflating: milli_imagenet/train/elephant_246301812_bd89ba2fe0.jpg
#   inflating: milli_imagenet/train/dog_2192510042_0bbe6ef4fb.jpg
#   inflating: milli_imagenet/train/elephant_793170418_d9c66e1c06.jpg
#   inflating: milli_imagenet/train/elephant_27473094_9124aaf8b6.jpg
#   inflating: milli_imagenet/train/cat_1483890465_2bc92663ca.jpg
#   inflating: milli_imagenet/train/dog_426580611_4391fe2d16.jpg
#   inflating: milli_imagenet/train/car_2494857142_c045b4f429.jpg
#   inflating: milli_imagenet/train/cat_504761099_f551dcc330.jpg
#   inflating: milli_imagenet/train/airplane_2583006281_1a66303a08.jpg
#   inflating: milli_imagenet/train/airplane_2110882407_db1564e294.jpg
#   inflating: milli_imagenet/train/cat_1072969881_c8cf8109fc.jpg
#   inflating: milli_imagenet/train/dog_1485445731_7ec563b052.jpg
#   inflating: milli_imagenet/train/cat_347285520_c9f4dc030b.jpg
#   inflating: milli_imagenet/train/car_950211203_8486492df7.jpg
#   inflating: milli_imagenet/train/elephant_420995582_1e576d26d6.jpg
#   inflating: milli_imagenet/train/cat_464436117_d10c4e637a.jpg
#   inflating: milli_imagenet/train/car_2483148791_79d334bfb0.jpg
#   inflating: milli_imagenet/train/cat_389105593_354165d41a.jpg
#   inflating: milli_imagenet/train/airplane_279551945_9ceb21dbba.jpg
#   inflating: milli_imagenet/train/airplane_1541385583_380c22306a.jpg
#   inflating: milli_imagenet/train/cat_472723151_d6e5cede19.jpg
#   inflating: milli_imagenet/train/cat_62347433_f519750764.jpg
#   inflating: milli_imagenet/train/cat_1775915054_554af9fdd7.jpg
#   inflating: milli_imagenet/train/elephant_20362537_956ae4bfbd.jpg
#   inflating: milli_imagenet/train/dog_143617264_f622cf7db8.jpg
#   inflating: milli_imagenet/train/elephant_329431271_10c203afd1.jpg
#   inflating: milli_imagenet/train/dog_140851314_0b7c154bcc.jpg
#   inflating: milli_imagenet/train/dog_406635927_1cefe86380.jpg
#   inflating: milli_imagenet/train/airplane_324141414143.jpg
#   inflating: milli_imagenet/train/car_2599635685_e5bc82643f.jpg
#   inflating: milli_imagenet/train/dog_503138718_cbd7cc0012.jpg
#   inflating: milli_imagenet/train/cat_178552778_3d8c84d090.jpg
#   inflating: milli_imagenet/train/elephant_262793989_63b199b8b3.jpg
#   inflating: milli_imagenet/train/elephant_165870036_f6731a5c66.jpg
#   inflating: milli_imagenet/train/elephant_39120659_9a42e43e9d.jpg
#   inflating: milli_imagenet/train/cat_509807655_0be4c6921f.jpg
#   inflating: milli_imagenet/train/cat_1095526988_7a288676e1.jpg
#   inflating: milli_imagenet/train/elephant_756958798_ed624c90fc.jpg
#   inflating: milli_imagenet/train/elephant_52774012_f70b1e12f8.jpg
#   inflating: milli_imagenet/train/elephant_300447424_137b1131b2.jpg
#   inflating: milli_imagenet/train/dog_111777013_ea18a69caf.jpg
#   inflating: milli_imagenet/train/dog_739803901_d04792b8c3.jpg
#   inflating: milli_imagenet/train/car_47635237_1e85ffaf2e.jpg
#   inflating: milli_imagenet/train/car_2619327487_017fededca.jpg
#   inflating: milli_imagenet/train/dog_249881952_cd4e9c3cd0.jpg
#   inflating: milli_imagenet/train/airplane_424904790_c3b90d8be0.jpg
#   inflating: milli_imagenet/train/cat_125127356_4ee7bde116.jpg
#   inflating: milli_imagenet/train/car_2583556570_6bf3197b8c.jpg
#   inflating: milli_imagenet/train/elephant_847919332_a61b398015.jpg
#   inflating: milli_imagenet/train/elephant_215475669_9d447b0edd.jpg
#   inflating: milli_imagenet/train/dog_2062640615_eee2e0b952.jpg
#   inflating: milli_imagenet/train/airplane_237218693_f3400a0676.jpg
#   inflating: milli_imagenet/train/dog_512777356_cc623da075.jpg
#   inflating: milli_imagenet/train/airplane_2166665782_f1ea22b1a5.jpg
#   inflating: milli_imagenet/train/airplane_2291087620_aec04250f5.jpg
#   inflating: milli_imagenet/train/elephant_1797110823_d89a8ea8f8.jpg
#   inflating: milli_imagenet/train/airplane_449795604_a49f916136.jpg
#   inflating: milli_imagenet/train/cat_134214901_b79b59a8b0.jpg
#   inflating: milli_imagenet/train/cat_1326762140_da4f016132.jpg
#   inflating: milli_imagenet/train/dog_1844653713_5fc15cb6c8.jpg
#   inflating: milli_imagenet/train/dog_1749059808_f528e332a9.jpg
#   inflating: milli_imagenet/train/cat_846882986_4de328b6b4.jpg
#   inflating: milli_imagenet/train/dog_178779808_a24e34cb25.jpg
#   inflating: milli_imagenet/train/cat_845155935_1df15c0164.jpg
#   inflating: milli_imagenet/train/dog_492309271_2eb097d699.jpg
#   inflating: milli_imagenet/train/elephant_1599373937_311ef4b444.jpg
#   inflating: milli_imagenet/train/cat_339533190_9cf17b4d96.jpg
#   inflating: milli_imagenet/train/airplane_116852124_1a52caa0a8.jpg
#   inflating: milli_imagenet/train/elephant_311928263_610650c9fb.jpg
#   inflating: milli_imagenet/train/cat_1407544421_76a8d1099a.jpg
#   inflating: milli_imagenet/train/cat_838925728_5b6e50d797.jpg
#   inflating: milli_imagenet/train/dog_381342603_81db58bea4.jpg
#   inflating: milli_imagenet/train/airplane_2707596196_1047fa7b74.jpg
#   inflating: milli_imagenet/train/elephant_99995258_5d66772a78.jpg
#   inflating: milli_imagenet/train/dog_2085768823_a0afd2773f.jpg
#   inflating: milli_imagenet/train/airplane_2357605177_7c9d333532.jpg
#   inflating: milli_imagenet/train/car_1260326450_01fefc2d7a.jpg
#   inflating: milli_imagenet/train/cat_1986619993_4d2e3a5442.jpg
#   inflating: milli_imagenet/train/airplane_2049128902_d4c270cada.jpg
#   inflating: milli_imagenet/train/cat_339697706_46ef43d3f1.jpg
#   inflating: milli_imagenet/train/dog_426618727_f2e711c7eb.jpg
#   inflating: milli_imagenet/train/car_1719163907_860883cbe8.jpg
#   inflating: milli_imagenet/train/airplane_2405170905_3e848336d7.jpg
#   inflating: milli_imagenet/train/airplane_290988303_b8a34724a2.jpg
#   inflating: milli_imagenet/train/car_1259513947_cfff1b7336.jpg
#   inflating: milli_imagenet/train/cat_469376607_5a1f033463.jpg
#   inflating: milli_imagenet/train/car_2225360964_a948346207.jpg
#   inflating: milli_imagenet/train/dog_509558025_17dc760a6b.jpg
#   inflating: milli_imagenet/train/cat_2221101205_a3ab95041e.jpg
#   inflating: milli_imagenet/train/cat_75714427_07216dd49d.jpg
#   inflating: milli_imagenet/train/dog_1814077511_14213d6767.jpg
#   inflating: milli_imagenet/train/dog_1589046073_5420d1ca1d.jpg
#   inflating: milli_imagenet/train/elephant_456667505_14c4a06f20.jpg
#   inflating: milli_imagenet/train/elephant_449704285_7a3e7cd2e3.jpg
#   inflating: milli_imagenet/train/airplane_2393186173_5df8796c80.jpg
#   inflating: milli_imagenet/train/car_2586393985_813dd4a8d7.jpg
#   inflating: milli_imagenet/train/dog_406806420_7585703d38.jpg
#   inflating: milli_imagenet/train/car_936972157_be0a44bd1d.jpg
#   inflating: milli_imagenet/train/car_2590939229_e322b52f53.jpg
#   inflating: milli_imagenet/train/airplane_1731472229_6bf491f5bc.jpg
#   inflating: milli_imagenet/train/elephant_1410087513_228d547b74.jpg
#   inflating: milli_imagenet/train/cat_456913874_a4c5dab950.jpg
#   inflating: milli_imagenet/train/car_2692553168_7f46d8d5f6.jpg
#   inflating: milli_imagenet/train/dog_100962839_4828f9b1cf.jpg
#   inflating: milli_imagenet/train/dog_406691012_817bbeba9f.jpg
#   inflating: milli_imagenet/train/car_2633668806_2b68667020.jpg
#   inflating: milli_imagenet/train/elephant_2038153276_bb2ddaf570.jpg
#   inflating: milli_imagenet/train/elephant_476242081_cd0302e195.jpg
#   inflating: milli_imagenet/train/elephant_1355693327_f53eeb6706.jpg
#   inflating: milli_imagenet/train/elephant_226299175_f29676a940.jpg
#   inflating: milli_imagenet/train/airplane_261275907_01bade9983.jpg
#   inflating: milli_imagenet/train/car_2431149099_6ce32c4762.jpg
#   inflating: milli_imagenet/train/car_2628194225_3254e2624d.jpg
#   inflating: milli_imagenet/train/cat_68206548_a2a88cc200.jpg
#   inflating: milli_imagenet/train/airplane_930116286_40004772c5.jpg
#   inflating: milli_imagenet/train/cat_1809362680_ba9213d4f5.jpg
#   inflating: milli_imagenet/train/elephant_1371597085_668b079f8d.jpg
#   inflating: milli_imagenet/train/cat_1413814714_f174b7a5af.jpg
#   inflating: milli_imagenet/train/airplane_605227812_815c3f2106.jpg
#   inflating: milli_imagenet/train/car_2576400220_27b005d234.jpg
#   inflating: milli_imagenet/train/cat_433443071_a624cb32e9.jpg
#   inflating: milli_imagenet/train/car_2512760701_8cbe2ed2fd.jpg
#   inflating: milli_imagenet/train/dog_2016460681_c12044f593.jpg
#   inflating: milli_imagenet/train/cat_201964852_1817e956c1.jpg
#   inflating: milli_imagenet/train/dog_113917933_d5629f615c.jpg
#   inflating: milli_imagenet/train/airplane_17669410_8ab34f9f7f.jpg
#   inflating: milli_imagenet/train/elephant_915869297_fbbd74b73d.jpg
#   inflating: milli_imagenet/train/cat_520562987_e5a8ca1b73.jpg
#   inflating: milli_imagenet/train/elephant_52773888_f59989d4ff.jpg
#   inflating: milli_imagenet/train/elephant_176912049_634aaee234.jpg
#   inflating: milli_imagenet/train/elephant_81317196_a96223ef04.jpg
#   inflating: milli_imagenet/train/airplane_84652928_1e5f946977.jpg
#   inflating: milli_imagenet/train/dog_1045004536_ea846b9f88.jpg
#   inflating: milli_imagenet/train/dog_891910188_c42f1f80d9.jpg
#   inflating: milli_imagenet/train/car_2381680146_f3337204a4.jpg
#   inflating: milli_imagenet/train/car_2691435561_19680a057a.jpg
#   inflating: milli_imagenet/train/cat_466996656_868d772341.jpg
#   inflating: milli_imagenet/train/airplane_388364576_3b1ef11d02.jpg
#   inflating: milli_imagenet/train/dog_1891011832_cb5d5098c2.jpg
#   inflating: milli_imagenet/train/car_2350299260_e240d45df4.jpg
#   inflating: milli_imagenet/train/car_2464092263_06384b6ee5.jpg
#   inflating: milli_imagenet/train/elephant_379172906_fd13b43e27.jpg
#   inflating: milli_imagenet/train/cat_718539612_b344a6a2c8.jpg
#   inflating: milli_imagenet/train/cat_7938264_9b0e24f0f7.jpg
#   inflating: milli_imagenet/train/airplane_2465717341_0fe4f16f30.jpg
#   inflating: milli_imagenet/train/elephant_2038380488_c292f1b782.jpg
#   inflating: milli_imagenet/train/car_2359095828_4b590d9ec7.jpg
#   inflating: milli_imagenet/train/dog_437188714_a6c271a7b2.jpg
#   inflating: milli_imagenet/train/cat_11841850_fa98242c6a.jpg
#   inflating: milli_imagenet/train/airplane_456057568_afafd5dd46.jpg
#   inflating: milli_imagenet/train/airplane_417566635_abe4a920b5.jpg
#   inflating: milli_imagenet/train/airplane_2410687973_774a8e1848.jpg
#   inflating: milli_imagenet/train/car_2431968404_7b6f24e053.jpg
#   inflating: milli_imagenet/train/cat_465423833_3a7229f251.jpg
#   inflating: milli_imagenet/train/cat_1728856065_61f4290857.jpg
#   inflating: milli_imagenet/train/cat_526980964_3f1a6fa364.jpg
#   inflating: milli_imagenet/train/airplane_604946715_b343afe46a.jpg
#   inflating: milli_imagenet/train/elephant_1068986661_7cc0df9a4c.jpg
#   inflating: milli_imagenet/train/airplane_1385059255_4a608b7e0f.jpg
#   inflating: milli_imagenet/train/dog_437195773_d2a202d39d.jpg
#   inflating: milli_imagenet/train/airplane_667898487_003069fb9e.jpg
#   inflating: milli_imagenet/train/elephant_847057903_78f8014971.jpg
#   inflating: milli_imagenet/train/cat_778132371_aabe7d2876.jpg
#   inflating: milli_imagenet/train/car_2663384793_2608e05f88.jpg
#   inflating: milli_imagenet/train/dog_436013849_6c5003a231.jpg
#   inflating: milli_imagenet/train/elephant_171247905_aa44f6ccb4.jpg
#   inflating: milli_imagenet/train/cat_1181154063_3a718ffe8d.jpg
#   inflating: milli_imagenet/train/cat_1612667428_4ea558e97b.jpg
#   inflating: milli_imagenet/train/elephant_376009394_aeafa0d8c4.jpg
#   inflating: milli_imagenet/train/car_2439114272_36ea943070.jpg
#   inflating: milli_imagenet/train/dog_329958161_ca74cdb415.jpg
#   inflating: milli_imagenet/train/airplane_549733728_8fc9ec082d.jpg
#   inflating: milli_imagenet/train/car_2452533800_2bc256f369.jpg
#   inflating: milli_imagenet/train/car_2319626512_73fe2db207.jpg
#   inflating: milli_imagenet/train/car_2504675586_4bbc1ec082.jpg
#   inflating: milli_imagenet/train/elephant_36404958_4078f4363a.jpg
#   inflating: milli_imagenet/train/cat_29478281_687a41c197.jpg
#   inflating: milli_imagenet/train/car_2331813646_8fef6cc060.jpg
#   inflating: milli_imagenet/train/dog_2004101695_eefe794968.jpg
#   inflating: milli_imagenet/train/cat_798193808_7aea050511.jpg
#   inflating: milli_imagenet/train/cat_1425549611_ee600950f7.jpg
#   inflating: milli_imagenet/train/elephant_1215025358_0b8bbe38b8.jpg
#   inflating: milli_imagenet/train/airplane_1977534068_f2c3a9c271.jpg
#   inflating: milli_imagenet/train/elephant_273914634_00e9f300e9.jpg
#   inflating: milli_imagenet/train/car_29891873_dc3d851b1d.jpg
#   inflating: milli_imagenet/train/car_2448297953_272c37af3d.jpg
#   inflating: milli_imagenet/train/elephant_173175331_80e422484a.jpg
#   inflating: milli_imagenet/train/dog_421685335_f7e8b86e6a.jpg
#   inflating: milli_imagenet/train/car_2232088465_17629e7959.jpg
#   inflating: milli_imagenet/train/cat_570837226_49dc1528f9.jpg
#   inflating: milli_imagenet/train/car_2648602199_33653b9938.jpg
#   inflating: milli_imagenet/train/airplane_2467524810_5d89175754.jpg
#   inflating: milli_imagenet/train/elephant_329433376_343b1f7582.jpg
#   inflating: milli_imagenet/train/car_2600019140_67b6c145c2.jpg
#   inflating: milli_imagenet/train/elephant_170309517_c6c1b5c915.jpg
#   inflating: milli_imagenet/train/cat_649739480_0491b2db5e.jpg
#   inflating: milli_imagenet/train/elephant_3355786_fc91a1811c.jpg
#   inflating: milli_imagenet/train/airplane_1114918981_28de3f9b8f.jpg
#   inflating: milli_imagenet/train/dog_688939929_9feaa7e4f9.jpg
#   inflating: milli_imagenet/train/cat_129108705_e66b66c48c.jpg
#   inflating: milli_imagenet/train/cat_1453599760_6d1b56a759.jpg
#   inflating: milli_imagenet/train/cat_2143568817_87cd9db05f.jpg
#   inflating: milli_imagenet/train/car_2383370810_bea2b651b8.jpg
#   inflating: milli_imagenet/train/cat_2222865249_1d23861afa.jpg
#   inflating: milli_imagenet/train/dog_437195837_62f9c78e5a.jpg
#   inflating: milli_imagenet/train/airplane_2675903015_2f3bc2d7c9.jpg
#   inflating: milli_imagenet/train/cat_104390249_b87e26dee7.jpg
#   inflating: milli_imagenet/train/airplane_2724914815_151610eca6.jpg
#   inflating: milli_imagenet/train/airplane_2585676484_b0d9fe37c7.jpg
#   inflating: milli_imagenet/train/airplane_64831538_31889a4190.jpg
#   inflating: milli_imagenet/train/dog_392340820_200a4cbc4d.jpg
#   inflating: milli_imagenet/train/cat_906952515_2758937d79.jpg
#   inflating: milli_imagenet/train/airplane_2602427969_c132208676.jpg
#   inflating: milli_imagenet/train/dog_740665284_825f14c8e7.jpg
#   inflating: milli_imagenet/train/dog_1633050101_f09ef9b726.jpg
#   inflating: milli_imagenet/train/car_2697548163_4150a9abd6.jpg
#   inflating: milli_imagenet/train/airplane_19016283_03f8fce2de.jpg
#   inflating: milli_imagenet/train/cat_917206849_c44eec3096.jpg
#   inflating: milli_imagenet/train/car_2060359539_549fb9191a.jpg
#   inflating: milli_imagenet/train/car_2735197452_60b4cdda68.jpg
#   inflating: milli_imagenet/train/airplane_1510178251_ccca2d1547.jpg
#   inflating: milli_imagenet/train/cat_70401318_5071e1729d.jpg
#   inflating: milli_imagenet/train/car_2599723500_85b30b9305.jpg
#   inflating: milli_imagenet/train/car_1510993471_913a3912b9.jpg
#   inflating: milli_imagenet/train/airplane_9876543456.jpg
#   inflating: milli_imagenet/train/dog_427046325_87d3539524.jpg
#   inflating: milli_imagenet/train/cat_396186579_62d6907b77.jpg
#   inflating: milli_imagenet/train/cat_196885432_3bca121058.jpg
#   inflating: milli_imagenet/train/car_2061069980_a1b87aaef1.jpg
#   inflating: milli_imagenet/train/dog_1619436512_37e37aa761.jpg
#   inflating: milli_imagenet/train/car_1895554483_e861f59c9b.jpg
#   inflating: milli_imagenet/train/airplane_345090920_9d05ea34f5.jpg
#   inflating: milli_imagenet/train/car_2466037491_2359298273.jpg
#   inflating: milli_imagenet/train/dog_40032450_89ab9c620f.jpg
#   inflating: milli_imagenet/train/cat_441068932_8915b6de4c.jpg
#   inflating: milli_imagenet/train/dog_185003176_ad9dc0aabb.jpg
#   inflating: milli_imagenet/train/elephant_74462886_3fc56ad8da.jpg
#   inflating: milli_imagenet/train/airplane_88395459_992dabe764.jpg
#   inflating: milli_imagenet/train/dog_253261970_d7b656a9f5.jpg
#   inflating: milli_imagenet/train/cat_1323581252_5cd7421812.jpg
#   inflating: milli_imagenet/train/elephant_170320513_325553770f.jpg
#   inflating: milli_imagenet/train/car_2604149964_065b86f906.jpg
#   inflating: milli_imagenet/train/elephant_108331635_4dccd99e9d.jpg
#   inflating: milli_imagenet/train/elephant_422223218_f2659d3ed9.jpg
#   inflating: milli_imagenet/train/elephant_2088386708_b84a8eb857.jpg
#   inflating: milli_imagenet/train/cat_166840712_b95a6565bb.jpg
#   inflating: milli_imagenet/train/dog_2055437512_6ccd4b5949.jpg
#   inflating: milli_imagenet/train/dog_79947983_c3c808859e.jpg
#   inflating: milli_imagenet/train/dog_427080674_ec2ef34db5.jpg
#   inflating: milli_imagenet/train/car_2476601060_dce65d9c01.jpg
#   inflating: milli_imagenet/train/car_2721938867_29895a47e6.jpg
#   inflating: milli_imagenet/train/elephant_842146094_ba09d23e0d.jpg
#   inflating: milli_imagenet/train/elephant_182069030_3078757d15.jpg
#   inflating: milli_imagenet/train/car_1679332342_a7553bd16b.jpg
#   inflating: milli_imagenet/train/cat_393656824_bd89c512d0.jpg
#   inflating: milli_imagenet/train/airplane_257796960_f2b410e9cd.jpg
#   inflating: milli_imagenet/train/airplane_196815033_f9f5b968aa.jpg
#   inflating: milli_imagenet/train/elephant_742904115_ad0fb96187.jpg
#   inflating: milli_imagenet/train/elephant_543221395_509bcbdbdd.jpg
#   inflating: milli_imagenet/train/elephant_518813412_12505cf38a.jpg
#   inflating: milli_imagenet/train/dog_354345091_fd0785b6f8.jpg
#   inflating: milli_imagenet/train/elephant_311927630_33a92c13b6.jpg
#   inflating: milli_imagenet/train/elephant_123639259_adf0f73915.jpg
#   inflating: milli_imagenet/train/airplane_1403066022_7f2226b1f4.jpg
#   inflating: milli_imagenet/train/dog_1138807082_9fffec94d2.jpg
#   inflating: milli_imagenet/train/elephant_171251359_939ba015aa.jpg
#   inflating: milli_imagenet/train/car_1700378831_db202ab909.jpg
#   inflating: milli_imagenet/train/airplane_2258717758_79fbf456e9.jpg
#   inflating: milli_imagenet/train/airplane_2165869557_a53b86e0ee.jpg
#   inflating: milli_imagenet/train/airplane_2337490984_291b01312b.jpg
#   inflating: milli_imagenet/train/car_2432091658_c9e19cf1f8.jpg
#   inflating: milli_imagenet/train/cat_800528750_8224be0489.jpg
#   inflating: milli_imagenet/train/cat_454081236_ec80633461.jpg
#   inflating: milli_imagenet/train/airplane_41760512_1905fa4632.jpg
#   inflating: milli_imagenet/train/elephant_1025410653_2fe15822ea.jpg
#   inflating: milli_imagenet/train/car_2431260901_d97aa49f22.jpg
#   inflating: milli_imagenet/train/cat_663418041_3f7c77d19a.jpg
#   inflating: milli_imagenet/train/airplane_400350015_a74a725f9e.jpg
#   inflating: milli_imagenet/train/airplane_48629591_63b3ba3ed5.jpg
#   inflating: milli_imagenet/train/dog_406714879_928435958c.jpg
#   inflating: milli_imagenet/train/cat_777007108_7185b9178d.jpg
#   inflating: milli_imagenet/train/airplane_388364587_64b2370a82.jpg
#   inflating: milli_imagenet/train/elephant_692108952_9532cbf31a.jpg
#   inflating: milli_imagenet/train/elephant_2207867949_53b08fb27f.jpg
#   inflating: milli_imagenet/train/cat_164973134_d6799c5db4.jpg
#   inflating: milli_imagenet/train/cat_1371892048_9e9f3ee318.jpg
#   inflating: milli_imagenet/train/car_2589437780_5b2100db77.jpg
#   inflating: milli_imagenet/train/airplane_1255927570_ebb5676a1a.jpg
#   inflating: milli_imagenet/train/car_2224509128_18482bc226.jpg
#   inflating: milli_imagenet/train/car_2210892916_cf13b68b8a.jpg
#   inflating: milli_imagenet/train/elephant_342367081_234bf66913.jpg
#   inflating: milli_imagenet/train/elephant_289736736_a424175449.jpg
#   inflating: milli_imagenet/train/airplane_2075802956_fdf9d917a7.jpg
#   inflating: milli_imagenet/train/car_2491559585_1ef4bf1629.jpg
#   inflating: milli_imagenet/train/car_2284242336_097d8aed4c.jpg
#   inflating: milli_imagenet/train/car_1388826099_01505abea9.jpg
#   inflating: milli_imagenet/train/airplane_1509512914_0f7cc298a7.jpg
#   inflating: milli_imagenet/train/cat_2229414874_ed4524d3dd.jpg
#   inflating: milli_imagenet/train/elephant_170299685_7d3150eac0.jpg
#   inflating: milli_imagenet/train/car_2451494761_39155daeea.jpg
#   inflating: milli_imagenet/train/airplane_233617389_831644ed1d.jpg
#   inflating: milli_imagenet/train/elephant_76574872_041e0901c2.jpg
# ...
#   inflating: milli_imagenet/train/dog_312730899_e3e2f9b604.jpg
#   inflating: milli_imagenet/train/cat_1372697816_2233d0939b.jpg
#   inflating: milli_imagenet/train/car_2288154692_ee16396db6.jpg
#   inflating: milli_imagenet/train/airplane_150553917_8cc96f4039.jpg
#   inflating: milli_imagenet/train/cat_1130458060_b77117482a.jpg
#   inflating: milli_imagenet/train/cat_2053614070_1ed1fedfff.jpg
#   inflating: milli_imagenet/train/elephant_847919306_2b44854321.jpg
#   inflating: milli_imagenet/train/dog_426950338_a40e466aef.jpg
#   inflating: milli_imagenet/train/cat_263883487_ff49977e8c.jpg
#   inflating: milli_imagenet/train/elephant_374182918_81e1d22a0c.jpg
#   inflating: milli_imagenet/train/elephant_1443650090_6a5a672ee2.jpg
#   inflating: milli_imagenet/train/dog_1362337622_6715d73cd5.jpg
#   inflating: milli_imagenet/train/car_2533882384_32c808c546.jpg
#   inflating: milli_imagenet/train/elephant_743822064_7308559384.jpg
#   inflating: milli_imagenet/train/elephant_1574770997_e8303688d8.jpg
#   inflating: milli_imagenet/train/cat_797587495_23df166c06.jpg
#   inflating: milli_imagenet/train/car_2577062251_b7730929e5.jpg
#   inflating: milli_imagenet/train/elephant_129281385_1a1eeb729f.jpg
#   inflating: milli_imagenet/train/airplane_15704914_ea05e564f3.jpg
#   inflating: milli_imagenet/train/airplane_528361063_bedebe89b7.jpg
#   inflating: milli_imagenet/train/airplane_2038919327_79e97b380b.jpg
#   inflating: milli_imagenet/train/airplane_1385453119_2b344e7708.jpg
#   inflating: milli_imagenet/train/car_2600152632_6d4f1d7f4b.jpg
#   inflating: milli_imagenet/train/cat_508132866_4d69bae597.jpg
#   inflating: milli_imagenet/train/car_2707694861_b207366a89.jpg
#   inflating: milli_imagenet/train/elephant_1409858825_141a5df03d.jpg
#   inflating: milli_imagenet/train/dog_492307159_51c4c56907.jpg
#   inflating: milli_imagenet/train/car_195987340_deadffe423.jpg
#   inflating: milli_imagenet/train/airplane_1037094054_6f3efbae8f.jpg
#   inflating: milli_imagenet/train/airplane_2629026000_47d153f84f.jpg
#   inflating: milli_imagenet/train/dog_406764144_ca23bc7907.jpg
#   inflating: milli_imagenet/train/dog_2021461032_1fee18b98b.jpg
#   inflating: milli_imagenet/train/airplane_432305973_7ecbe9d2c4.jpg
#   inflating: milli_imagenet/train/elephant_499280318_5e706c8316.jpg
#   inflating: milli_imagenet/train/car_888121_b8c0a747fa.jpg
#   inflating: milli_imagenet/train/elephant_173174809_69004c84e6.jpg
#   inflating: milli_imagenet/train/car_2454464852_93202af2ca.jpg
#   inflating: milli_imagenet/train/dog_94765224_b62d10f5bf.jpg
#   inflating: milli_imagenet/train/dog_24600676_1eed9941db.jpg
#   inflating: milli_imagenet/train/car_2409438069_7afa0e81c7.jpg
#   inflating: milli_imagenet/train/airplane_1099941359_7ae0572599.jpg
#   inflating: milli_imagenet/train/car_160484546_e0aac3cb54.jpg
#   inflating: milli_imagenet/train/cat_1336922314_8f4ef9aef6.jpg
#   inflating: milli_imagenet/train/dog_2034128795_248f24bed6.jpg
#   inflating: milli_imagenet/train/elephant_541688637_93504e95b4.jpg
#   inflating: milli_imagenet/train/dog_426617735_5b74ed234a.jpg
#   inflating: milli_imagenet/train/elephant_173174590_2fe3fb1695.jpg
#   inflating: milli_imagenet/train/cat_1195913329_72adfed00b.jpg
#   inflating: milli_imagenet/train/airplane_2270128078_48b9285f4a.jpg
#   inflating: milli_imagenet/train/airplane_495254441_f751d7c7d8.jpg
#   inflating: milli_imagenet/train/elephant_96758220_b196ca39b6.jpg
#   inflating: milli_imagenet/train/airplane_2165868395_2f965cecd3.jpg
#   inflating: milli_imagenet/train/dog_887932010_2b24d8be1d.jpg
#   inflating: milli_imagenet/train/cat_458865943_58cac7c564.jpg
#   inflating: milli_imagenet/train/airplane_423873432_95420959b6.jpg
#   inflating: milli_imagenet/train/elephant_399366378_f599879006.jpg
#   inflating: milli_imagenet/train/cat_255186483_ed62ee27d8.jpg
#   inflating: milli_imagenet/train/airplane_389647660_9f05c416f0.jpg
#   inflating: milli_imagenet/train/cat_299836529_e6ade8d23f.jpg
#   inflating: milli_imagenet/train/airplane_385346359_37fbe9ed65.jpg
#   inflating: milli_imagenet/train/car_2436617976_7bb581d2d0.jpg
#   inflating: milli_imagenet/train/cat_103392464_9743e196fb.jpg
#   inflating: milli_imagenet/train/dog_123347917_3e968b4384.jpg
#   inflating: milli_imagenet/train/cat_1845262280_b5ba3ffa6f.jpg
#   inflating: milli_imagenet/train/dog_125859149_7ba63bb152.jpg
#   inflating: milli_imagenet/train/dog_103868220_d232b4db68.jpg
#   inflating: milli_imagenet/train/airplane_1399804209_24dd4e9ed4.jpg
#   inflating: milli_imagenet/train/car_2295426900_bbfa44a917.jpg
#   inflating: milli_imagenet/train/elephant_1120292274_f6cf1b3f2e.jpg
#   inflating: milli_imagenet/train/dog_104255595_2ed3867875.jpg
#   inflating: milli_imagenet/train/airplane_128447528_a48d3519de.jpg
#   inflating: milli_imagenet/train/car_2570822777_30d2c5d3cc.jpg
#   inflating: milli_imagenet/train/cat_510864988_425996c143.jpg
#   inflating: milli_imagenet/train/dog_322693296_8a7418c9f3.jpg
#   inflating: milli_imagenet/train/car_2467352715_a292bd40e7.jpg
#   inflating: milli_imagenet/train/dog_1517736008_ce4a644ba9.jpg
#   inflating: milli_imagenet/train/dog_314576644_45e4dd4cc4.jpg
#   inflating: milli_imagenet/train/elephant_1192821894_3d499c9f6b.jpg
#   inflating: milli_imagenet/train/cat_778142671_b39d893f71.jpg
#   inflating: milli_imagenet/train/cat_42584669_6ab87d4ca1.jpg
#   inflating: milli_imagenet/train/car_2685497486_0706dd9d82.jpg
#   inflating: milli_imagenet/train/airplane_2322787253_f6f7b74596.jpg
#   inflating: milli_imagenet/train/car_2246512936_00d03fb490.jpg
#   inflating: milli_imagenet/train/airplane_117774272_fe7c43ffbc.jpg
#   inflating: milli_imagenet/train/cat_49606677_3e64cc676e.jpg
#   inflating: milli_imagenet/train/elephant_1372523762_3a0b0fd24b.jpg
#   inflating: milli_imagenet/train/dog_8333029_c60053a5ce.jpg
#   inflating: milli_imagenet/train/airplane_229797795_e12081dda1.jpg
#   inflating: milli_imagenet/train/airplane_291232749_e2dbbecc2e.jpg
#   inflating: milli_imagenet/train/car_2335896543.jpg
#   inflating: milli_imagenet/train/elephant_284351909_3feabcbffc.jpg
#   inflating: milli_imagenet/train/car_2667551478_90e499d286.jpg
#   inflating: milli_imagenet/train/dog_355626022_44a32dd17a.jpg
#   inflating: milli_imagenet/train/dog_487311931_b1ab9e5bb3.jpg
#   inflating: milli_imagenet/train/dog_106947824_3c2d4a4abe.jpg
#   inflating: milli_imagenet/train/elephant_187382191_4b7eaf65fc.jpg
#   inflating: milli_imagenet/train/cat_42134687_2dcbca7ea1.jpg
#   inflating: milli_imagenet/train/dog_2195511772_767c75b800.jpg
#   inflating: milli_imagenet/train/airplane_100574956_ccfcc18d73.jpg
#   inflating: milli_imagenet/train/airplane_1051112027_f4e0a701b2.jpg
#   inflating: milli_imagenet/train/dog_25516873_a2f3c2a231.jpg
#   inflating: milli_imagenet/train/car_2661009967_ce8c189c48.jpg
#   inflating: milli_imagenet/train/elephant_171247473_52ecaae406.jpg
#   inflating: milli_imagenet/train/airplane_213303085_80e6f25f1b.jpg
#   inflating: milli_imagenet/train/dog_511689397_c9e2b48f39.jpg
#   inflating: milli_imagenet/train/cat_596906845_87bd2499df.jpg
#   inflating: milli_imagenet/train/airplane_528077003_23ae3a6997.jpg
#   inflating: milli_imagenet/train/elephant_543112586_b428a93db5.jpg
#   inflating: milli_imagenet/train/dog_146461998_a2c11854c6.jpg
#   inflating: milli_imagenet/train/elephant_2177734660_a4a9176274.jpg
#   inflating: milli_imagenet/train/airplane_566779893_ce03b1d528.jpg
#   inflating: milli_imagenet/train/cat_516316867_882eecb7ba.jpg
#   inflating: milli_imagenet/train/dog_140532446_4ade7b6001.jpg
#   inflating: milli_imagenet/train/airplane_1383638808_e3cdb32c54.jpg
#   inflating: milli_imagenet/train/cat_807830062_43db2901c8.jpg
#   inflating: milli_imagenet/train/elephant_1337362441_59652d92bc.jpg
#   inflating: milli_imagenet/train/cat_2019585492_8915f64bde.jpg
#   inflating: milli_imagenet/train/cat_818198506_e1d7c3a16c.jpg
#   inflating: milli_imagenet/train/airplane_2230003421_45623b4388.jpg
#   inflating: milli_imagenet/train/airplane_2057605454_904fed61e2.jpg
#   inflating: milli_imagenet/train/car_153488067_a64a8eafa0.jpg
#   inflating: milli_imagenet/train/airplane_220719793_408d25b459.jpg
#   inflating: milli_imagenet/train/car_2301252128_061387e023.jpg
#   inflating: milli_imagenet/train/airplane_181817215_f29a204095.jpg
#   inflating: milli_imagenet/train/airplane_1976721688_0aa22c4469.jpg
#   inflating: milli_imagenet/train/elephant_288773629_bff278d5b6.jpg
#   inflating: milli_imagenet/train/cat_456913958_2852b52521.jpg
#   inflating: milli_imagenet/train/car_1389127753_0c90cae3d8.jpg
#   inflating: milli_imagenet/train/dog_492305013_5b048e2bbc.jpg
#   inflating: milli_imagenet/train/cat_2221095383_6fb6fff22e.jpg
#   inflating: milli_imagenet/train/dog_312943903_aa0b5a8c05.jpg
#   inflating: milli_imagenet/train/elephant_225554695_b1a2fbdfca.jpg
#   inflating: milli_imagenet/train/airplane_838419299_b3c260232a.jpg
#   inflating: milli_imagenet/train/elephant_879887722_f9b694e107.jpg
#   inflating: milli_imagenet/train/dog_426607926_db3bc3d7ea.jpg
#   inflating: milli_imagenet/train/dog_125896862_aea45a18ee.jpg
#   inflating: milli_imagenet/train/car_2483144533_b4c8ddc062.jpg
#   inflating: milli_imagenet/train/car_2590057056_eb3da558fa.jpg
#   inflating: milli_imagenet/train/elephant_215551816_22ebb06cd9.jpg
#   inflating: milli_imagenet/train/car_2176686754_a1c6c08328.jpg
#   inflating: milli_imagenet/train/elephant_246302635_0ae438658c.jpg
#   inflating: milli_imagenet/train/airplane_2312885795_7510d5de23.jpg
#   inflating: milli_imagenet/train/car_1603630995_6d82cee3b3.jpg
#   inflating: milli_imagenet/train/airplane_306393347_533824f619.jpg
#   inflating: milli_imagenet/train/airplane_17055170_c500725723.jpg
#   inflating: milli_imagenet/train/elephant_157604384_ee440d06ff.jpg
#   inflating: milli_imagenet/train/airplane_388347692_7f189e4a1b.jpg
#   inflating: milli_imagenet/train/elephant_374186554_7c629ce2c8.jpg
#   inflating: milli_imagenet/train/car_2301958002_a752deccc7.jpg
#   inflating: milli_imagenet/train/airplane_113404493_40cfb49dcd.jpg
#   inflating: milli_imagenet/train/elephant_438112447_b8c10bedf5.jpg
#   inflating: milli_imagenet/train/cat_806067483_6e158eebae.jpg
#   inflating: milli_imagenet/train/cat_512489293_24b4dcbc90.jpg
#   inflating: milli_imagenet/train/elephant_413343776_0a5c6dffff.jpg
#   inflating: milli_imagenet/train/airplane_2571877131_befb70207b.jpg
#   inflating: milli_imagenet/train/airplane_195838135_20a4a7c226.jpg
#   inflating: milli_imagenet/train/car_1344191937_6ee9102873.jpg
#   inflating: milli_imagenet/train/elephant_496973199_f73c1490b4.jpg
#   inflating: milli_imagenet/train/elephant_502841816_34b5e3fd03.jpg
#   inflating: milli_imagenet/train/dog_812682456_c04c9d6d82.jpg
#   inflating: milli_imagenet/train/airplane_217091105_e2f96e6480.jpg
#   inflating: milli_imagenet/train/cat_1074598047_9c49d82aca.jpg
#   inflating: milli_imagenet/train/elephant_35025871_d7873a88a7.jpg
#   inflating: milli_imagenet/train/airplane_861291324_2a397496dc.jpg
#   inflating: milli_imagenet/train/cat_1181724194_f3475d88fb.jpg
#   inflating: milli_imagenet/train/elephant_113236215_45bdefcb47.jpg
#   inflating: milli_imagenet/train/elephant_52774261_8c1bdc453d.jpg
#   inflating: milli_imagenet/train/dog_154066725_96258b6f39.jpg
#   inflating: milli_imagenet/train/elephant_171239865_42701377ba.jpg
#   inflating: milli_imagenet/train/cat_456928459_bad69ac884.jpg
#   inflating: milli_imagenet/train/dog_312298383_8984e4f5d5.jpg
#   inflating: milli_imagenet/train/dog_337123823_c7a59a44e9.jpg
#   inflating: milli_imagenet/train/car_457834210_05ee82006b.jpg
#   inflating: milli_imagenet/train/dog_431241988_cb3edbe73d.jpg
#   inflating: milli_imagenet/train/dog_959590073_b411321069.jpg
#   inflating: milli_imagenet/train/car_265689760_ec7aef7f13.jpg
#   inflating: milli_imagenet/train/cat_366783372_ca44c73bf6.jpg
#   inflating: milli_imagenet/train/elephant_23270726_ab97f0a99e.jpg
#   inflating: milli_imagenet/train/dog_2800688_afe83c164a.jpg
#   inflating: milli_imagenet/train/dog_426798942_f48bc57af7.jpg
#   inflating: milli_imagenet/train/car_1389950194_3a1d07fee0.jpg
#   inflating: milli_imagenet/train/airplane_125588728_568ae1f0b4.jpg
#   inflating: milli_imagenet/train/elephant_879887614_5d55b564da.jpg
#   inflating: milli_imagenet/train/cat_441054480_ec489cd7dc.jpg
#   inflating: milli_imagenet/train/car_2649449358_fed712e03d.jpg
#   inflating: milli_imagenet/train/elephant_173043507_3fe59df868.jpg
#   inflating: milli_imagenet/train/cat_127952190_8500465590.jpg
#   inflating: milli_imagenet/train/cat_1985735384_0507a2c073.jpg
#   inflating: milli_imagenet/train/dog_420787101_945dd39972.jpg
#   inflating: milli_imagenet/train/cat_459663811_5581b5e73e.jpg
#   inflating: milli_imagenet/train/cat_2134802268_f256811ce5.jpg
#   inflating: milli_imagenet/train/cat_416584755_9feba3ab33.jpg
#   inflating: milli_imagenet/train/car_2416297192_b4ff2a87d8.jpg
#   inflating: milli_imagenet/train/airplane_425399322_b8c9f3facf.jpg
#   inflating: milli_imagenet/train/elephant_252287217_c256bb690c.jpg
#   inflating: milli_imagenet/train/cat_1301334799_c33aa4368f.jpg
#   inflating: milli_imagenet/train/cat_439909665_262dc4a0fe.jpg
#   inflating: milli_imagenet/train/airplane_581969595_b183827f4c.jpg
#   inflating: milli_imagenet/train/elephant_456668125_c70bba9f72.jpg
#   inflating: milli_imagenet/train/car_2372975052_18475a0e89.jpg
#   inflating: milli_imagenet/train/airplane_2315991870_3cd2a3cded.jpg
#   inflating: milli_imagenet/train/dog_1407995394_22d8274d95.jpg
#   inflating: milli_imagenet/train/elephant_1397098508_c8d2ce1560.jpg
#   inflating: milli_imagenet/train/airplane_194351108_c3f14b576b.jpg
#   inflating: milli_imagenet/train/airplane_2562146713_50b4bf64f1.jpg
#   inflating: milli_imagenet/train/cat_130028450_3bea7e5120.jpg
#   inflating: milli_imagenet/train/elephant_117174963_cbd126a8ec.jpg
#   inflating: milli_imagenet/train/dog_426575540_ec97a25c8b.jpg
#   inflating: milli_imagenet/train/dog_426804592_4eb0888263.jpg
#   inflating: milli_imagenet/train/elephant_96983574_e3e18543b2.jpg
#   inflating: milli_imagenet/train/airplane_35607063_db8db2b29e.jpg
#   inflating: milli_imagenet/train/train.json
#   inflating: milli_imagenet/train/dog_489062128_67bba4fef1.jpg
#   inflating: milli_imagenet/train/elephant_1325452933_ef9bbe7529.jpg
#   inflating: milli_imagenet/train/cat_505539125_d7193beb76.jpg
#   inflating: milli_imagenet/train/cat_808812970_12dc7c4f73.jpg
#   inflating: milli_imagenet/train/names.txt
#   inflating: milli_imagenet/train/car_606181362_df658e612a.jpg
#   inflating: milli_imagenet/train/cat_520330558_682540ae3e.jpg
#   inflating: milli_imagenet/train/car_2661858724_158d6b3168.jpg
#   inflating: milli_imagenet/train/cat_433441976_dc6935c8e5.jpg
#   inflating: milli_imagenet/train/elephant_184549563_d043ddf94a.jpg
#   inflating: milli_imagenet/train/dog_39340254_4ea6a185d4.jpg
#   inflating: milli_imagenet/train/dog_1635365504_152b40563c.jpg
#   inflating: milli_imagenet/train/elephant_560897101_784224d03a.jpg
#   inflating: milli_imagenet/train/dog_69291956_f7be44e5cb.jpg
#   inflating: milli_imagenet/train/airplane_340424527_ec144ad25f.jpg
#   inflating: milli_imagenet/train/elephant_1393026831_7fdf37f14f.jpg
#   inflating: milli_imagenet/train/dog_1414089898_5858de884c.jpg
#   inflating: milli_imagenet/train/dog_574217027_6f7440218a.jpg
#   inflating: milli_imagenet/train/dog_1965271932_91c6255988.jpg
#   inflating: milli_imagenet/train/car_2724233665_47db8bb54b.jpg
#   inflating: milli_imagenet/train/cat_450160344_ebc6c5d6ea.jpg
#   inflating: milli_imagenet/train/airplane_197248946_e1e0c636db.jpg
#   inflating: milli_imagenet/train/airplane_2480212455_85835584db.jpg
#   inflating: milli_imagenet/train/cat_128230843_ffc20cb0b9.jpg
#   inflating: milli_imagenet/mapper.json
#   inflating: milli_imagenet/labelize.py

# %% [markdown]
# # Utils

# %%
# model.py

import torch.nn as nn
from collections import OrderedDict
from torchvision.models import resnet18

def get_model(args):
    # defining our deep learning architecture
    resnet = resnet18(pretrained=False)

    head = nn.Sequential(OrderedDict([
        ('fc1', nn.Linear(resnet.fc.in_features, 100)),
        ('added_relu1', nn.ReLU(inplace=True)),
        ('fc2', nn.Linear(100, 100)),
        ('added_relu2', nn.ReLU(inplace=True)),
        ('fc3', nn.Linear(100, 100))
    ]))

    resnet.fc = head

    if args.multiple_gpus:
        resnet = nn.DataParallel(resnet)

    resnet.to(args.device)

    return resnet

# %%
# ntxent.py

import torch

tau = 0.05

def loss_function(a, b):
    a_norm = torch.norm(a, dim=1).reshape(-1, 1)
    a_cap = torch.div(a, a_norm)
    b_norm = torch.norm(b, dim=1).reshape(-1, 1)
    b_cap = torch.div(b, b_norm)
    a_cap_b_cap = torch.cat([a_cap, b_cap], dim=0)
    a_cap_b_cap_transpose = torch.t(a_cap_b_cap)
    b_cap_a_cap = torch.cat([b_cap, a_cap], dim=0)
    sim = torch.mm(a_cap_b_cap, a_cap_b_cap_transpose)
    sim_by_tau = torch.div(sim, tau)
    exp_sim_by_tau = torch.exp(sim_by_tau)
    sum_of_rows = torch.sum(exp_sim_by_tau, dim=1)
    exp_sim_by_tau_diag = torch.diag(exp_sim_by_tau)
    numerators = torch.exp(torch.div(torch.nn.CosineSimilarity()(a_cap_b_cap, b_cap_a_cap), tau))
    denominators = sum_of_rows - exp_sim_by_tau_diag
    num_by_den = torch.div(numerators, denominators)
    neglog_num_by_den = -torch.log(num_by_den)
    return torch.mean(neglog_num_by_den)

# %%
# plotfuncs.py

import matplotlib.pyplot as plt
import seaborn as sns
import os

def plot_losses(arr, legend_name, fname):
    plt.figure(figsize=(10, 10))
    sns.set_style('darkgrid')
    plt.plot(arr)
    plt.legend(legend_name)
    plt.savefig(fname)
    plt.close()

# %%
# transforms.py

import torchvision

def get_color_distortion(s=1.0):
    color_jitter = torchvision.transforms.ColorJitter(0.8 * s, 0.8 * s, 0.8 * s, 0.2 * s)
    rnd_color_jitter =  torchvision.transforms.RandomApply([color_jitter], p=0.8)
    rnd_gray =  torchvision.transforms.RandomGrayscale(p=0.2)
    color_distort =  torchvision.transforms.Compose([rnd_color_jitter, rnd_gray])
    return color_distort

def deprocess_and_show(img_tensor):
    return  torchvision.transforms.Compose([
             torchvision.transforms.Normalize((0, 0, 0), (2, 2, 2)),
             torchvision.transforms.Normalize((-0.5, -0.5, -0.5), (1, 1, 1)),
             torchvision.transforms.ToPILImage()
          ])(img_tensor)

# %% [markdown]
# # Simclr

# %%
# simclr.py

import torch
import os
import numpy as np
from pathlib import Path

class SimCLR:
    def __init__(self, model, optimizer, dataloaders, loss_fn):
        self.model = model
        self.optimizer = optimizer
        self.dataloaders = dataloaders
        self.loss_fn = loss_fn
        
    def load_model(self, args):
        self.model.load_state_dict(torch.load(args.model_path), strict=False)

        if 'remove_top_layers' in vars(args):
            if args.remove_top_layers > 0:
                if args.multiple_gpus:
                    temp = list(self.model.module.fc.children())
                    if args.remove_top_layers <= len(temp):
                        self.model.module.fc = torch.nn.Sequential(*temp[:-args.remove_top_layers])
                else:
                    temp = list(self.model.fc.children())
                    if args.remove_top_layers <= len(temp):
                        self.model.fc = torch.nn.Sequential(*temp[:-args.remove_top_layers])

    def get_representations(self, args, mode):

        self.model.eval()

        res = {
        'X':torch.FloatTensor(),
        'Y':torch.LongTensor()
        }

        with torch.no_grad():
            for batch in self.dataloaders[mode]:
                x = batch['image'].to(args.device)
                label = batch['label']

                # get their outputs
                pred = self.model(x)

                res['X'] = torch.cat((res['X'], pred.cpu()))
                res['Y'] = torch.cat((res['Y'], label.cpu()))


        res['X'] = np.array(res['X'])
        res['Y'] = np.array(res['Y'])

        return res

    def train(self, args, num_epochs, log_interval):
        '''
        trains self.model on the train dataset for num_epochs
        and saves model and loss graph after log_interval
        number of epochs
        '''
        
        batch_losses = []

        def logging():
            # Plot the training losses Graph and save it
            
            Path(os.path.join(args.respath,"plots")).mkdir(parents=True, exist_ok=True)
            
            plot_losses(batch_losses, 'Training Losses', os.path.join(args.respath,'plots/training_losses.png'))
            
            Path(os.path.join(args.respath,"model")).mkdir(parents=True, exist_ok=True)
            
            # Store model and optimizer files
            torch.save(self.model.state_dict(), os.path.join(args.respath,"model/model.pth"))
            torch.save(self.optimizer.state_dict(), os.path.join(args.respath,"model/optimizer.pth"))
            np.savez(os.path.join(args.respath,"model/lossesfile"), np.array(batch_losses))
        
        self.model.train()
    
        # run a for loop for num_epochs
        for epoch in range(num_epochs):

            # run a for loop for each batch
            for batch in self.dataloaders['train']:

                # zero out grads
                self.optimizer.zero_grad()

                x1 = batch['image1'].to(args.device)
                x2 = batch['image2'].to(args.device)

                # get their outputs
                y1 = self.model(x1)
                y2 = self.model(x2)

                # get loss value
                loss = self.loss_fn(y1, y2)
                
                batch_losses.append(loss.cpu().data.item())

                # perform backprop on loss value to get gradient values
                loss.backward()

                # run the optimizer
                self.optimizer.step()
                
            if epoch%log_interval == log_interval-1:
                logging()
            
        logging()

# %%
# main.py

import argparse 
import torch
torch.cuda.empty_cache()
import torchvision
import gc

gc.collect()
from PIL import Image
import os
# '../milli_imagenet' 'results' -bs 250 -c --multiple_gpus
# making a command line interface
parser = argparse.ArgumentParser(description="This is the command line interface for the SimCLR framework for self-supervised learning. Below are the arguments which are required to run this program.")

parser.add_argument('datapath', type=str ,help="Path to the data root folder which contains train and test folders")

parser.add_argument('respath', type=str, help="Path to the results directory where the saved model and evaluation graphs would be stored. ")

parser.add_argument('-bs','--batch_size',default=250, type=int, help="The batch size for self-supervised training")

parser.add_argument('-nw','--num_workers',default=2,type=int,help="The number of workers for loading data")

parser.add_argument('-c','--cuda',action='store_true')

parser.add_argument('--multiple_gpus', action='store_true')

class TrainDataset(torch.utils.data.Dataset):

    def __init__(self, args):
        self.args = args
        
        with open(os.path.join(args.datapath, "train","names.txt")) as f:
            self.filenames = f.read().split('\n')
 
    def __len__(self):
        return len(self.filenames)

    def tensorify(self, img):
        return torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))(
            torchvision.transforms.ToTensor()(img)
            )

    def augmented_image(self, img):
        return get_color_distortion(1)(
            torchvision.transforms.RandomResizedCrop(224)(img)
            )    

    def __getitem__(self, idx):
        img = torchvision.transforms.Resize((224, 224))(
                                Image.open(os.path.join(args.datapath, 'train', self.filenames[idx])).convert('RGB')
                            )
        return {
        'image1':self.tensorify(
            self.augmented_image(img)
            ), 
        'image2': self.tensorify(
            self.augmented_image(img)
            )
        }

if __name__ == '__main__':
    argsv = ['./milli_imagenet', 'results', '-bs', '250', '-c', '--multiple_gpus']
    args = parser.parse_args(argsv)
    args.device = torch.device('cuda' if args.cuda else 'cpu')
    model = get_model(args)
    
    optimizer = torch.optim.Adam(
        model.parameters(), 
        lr=0.001, 
        weight_decay=1e-4
        )
    
    dataloaders = {}
    
    dataloaders['train'] = torch.utils.data.DataLoader(
        TrainDataset(args), 
        batch_size=args.batch_size, 
        shuffle=True, 
        num_workers=args.num_workers
        )
    
    loss_fn = loss_function
    simclrobj = SimCLR(model, optimizer, dataloaders, loss_fn)
    simclrobj.train(args, 200, 10)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)

# %%
# linear_evaluation.py

import argparse
import torch
import os
import torchvision
from PIL import Image
import json
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report

# making a command line interface
parser = argparse.ArgumentParser(description="This is the command line interface for the linear evaluation model")

parser.add_argument('datapath', type=str ,help="Path to the data root folder which contains train and test folders")

parser.add_argument('model_path', type=str, help="Path to the trained self-supervised model")

parser.add_argument('respath', type=str, help="Path to the results where the evaluation metrics would be stored. ")

parser.add_argument('-bs','--batch_size',default=250, type=int, help="The batch size for evaluation")

parser.add_argument('-nw','--num_workers',default=2,type=int,help="The number of workers for loading data")

parser.add_argument('-c','--cuda',action='store_true')

parser.add_argument('--multiple_gpus', action='store_true')

parser.add_argument('--remove_top_layers', default=1, type=int)


class TrainDataset(torch.utils.data.Dataset):

    def __init__(self, args):
        self.args = args
        
        with open(os.path.join(args.datapath,'train','train.json')) as f:
            self.filedict = json.load(f)

        with open(os.path.join(args.datapath,'mapper.json')) as f:
            self.mapper = json.load(f)

        self.filenames = list(self.filedict)
    
    def __len__(self):
        return len(self.filenames)

    def tensorify(self, img):
        return torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))(
            torchvision.transforms.ToTensor()(img)
            )

    def __getitem__(self, idx):
        return {
        'image':self.tensorify(
                    torchvision.transforms.Resize((224, 224))(
                                Image.open(os.path.join(args.datapath, 'train', self.filenames[idx])).convert('RGB')
                            )
                    ), 
        'label':self.mapper[self.filedict[self.filenames[idx]]]
        }


class TestDataset(torch.utils.data.Dataset):

    def __init__(self, args):
        self.args = args
        
        with open(os.path.join(args.datapath,'test','test.json')) as f:
            self.filedict = json.load(f)

        with open(os.path.join(args.datapath,'mapper.json')) as f:
            self.mapper = json.load(f)

        self.filenames = list(self.filedict)
    
    def __len__(self):
        return len(self.filenames)

    def tensorify(self, img):
        return torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))(
            torchvision.transforms.ToTensor()(img)
            )

    def __getitem__(self, idx):
        return {
        'image':self.tensorify(
                    torchvision.transforms.Resize((224, 224))(
                                Image.open(os.path.join(args.datapath, 'test', self.filenames[idx])).convert('RGB')
                            )
                    ), 
        'label':self.mapper[self.filedict[self.filenames[idx]]]
        }


if __name__ == '__main__':
    # '../milli_imagenet/' 'results/model/model.pth' 'results' -c --multiple_gpus -bs 125 
    argsv = ['./milli_imagenet/', 'results/model/model.pth', 'results', '-c' , '--multiple_gpus', '-bs', '125']
    args = parser.parse_args(argsv)
    args.device = torch.device('cuda' if args.cuda else 'cpu')
    model = get_model(args)

    dataloaders = {}
    
    dataloaders['train'] = torch.utils.data.DataLoader(
        TrainDataset(args), 
        batch_size=args.batch_size, 
        shuffle=False, 
        num_workers=args.num_workers
        )
    
    dataloaders['test'] = torch.utils.data.DataLoader(
        TestDataset(args), 
        batch_size=args.batch_size, 
        shuffle=False, 
        num_workers=args.num_workers
        )

    simclrobj = SimCLR(
        model, 
        None, 
        dataloaders, 
        None
        )
    simclrobj.load_model(args)


    reprs = {}

    for mode in ['train', 'test']:
        reprs[mode] = simclrobj.get_representations(args, mode=mode)    

    scaler = StandardScaler().fit(reprs['train']['X'])

    Xtrain = scaler.transform(reprs['train']['X'])
    Xtest = scaler.transform(reprs['test']['X'])

    clf = LogisticRegression(
        multi_class='multinomial', 
        max_iter=1000, 
        n_jobs=16,
        ).fit(
        Xtrain, reprs['train']['Y']
        )
    
    ypred = clf.predict(Xtest)
    print(
        classification_report(
        reprs['test']['Y'], 
        ypred, 
        digits=4, 
        target_names=['car', 'airplane', 'elephant', 'dog', 'cat'])
    )
# Out:
#               precision    recall  f1-score   support
#
#          car     0.8148    0.8800    0.8462        50
#     airplane     0.8222    0.7400    0.7789        50
#     elephant     0.6071    0.6800    0.6415        50
#          dog     0.4821    0.5400    0.5094        50
#          cat     0.6154    0.4800    0.5393        50
#
#     accuracy                         0.6640       250
#    macro avg     0.6683    0.6640    0.6631       250
# weighted avg     0.6683    0.6640    0.6631       250
