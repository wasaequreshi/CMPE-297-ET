# %% [markdown]
# # MMoE
#
# Source: https://github.com/drawbridge/keras-mmoe/

# %% [markdown]
# # Setup

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (5.0.2)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.62.3)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.5.30)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !mkdir '/root/.kaggle'
# !chmod 600 '/content/drive/My Drive/297 2021/kaggle.json'
# !cp '/content/drive/My Drive/297 2021/kaggle.json' '/root/.kaggle/'
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# !kaggle competitions download -c titanic
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# gender_submission.csv: Skipping, found more recently modified local copy (use --force to force download)
# test.csv: Skipping, found more recently modified local copy (use --force to force download)
# train.csv: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !ls
# Out:
# data  drive  gender_submission.csv  sample_data  test.csv  train.csv

# %% [markdown]
# # Data

# %%
# !mkdir data

# %%
# !wget -c https://github.com/drawbridge/keras-mmoe/raw/master/data/census-income.data.gz -P ./data
# !wget -c https://github.com/drawbridge/keras-mmoe/raw/master/data/census-income.test.gz -P ./data
# Out:
# --2021-11-06 21:26:11--  https://github.com/drawbridge/keras-mmoe/raw/master/data/census-income.data.gz
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/drawbridge/keras-mmoe/master/data/census-income.data.gz [following]
# --2021-11-06 21:26:12--  https://raw.githubusercontent.com/drawbridge/keras-mmoe/master/data/census-income.data.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 416 Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.
#
# --2021-11-06 21:26:12--  https://github.com/drawbridge/keras-mmoe/raw/master/data/census-income.test.gz
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/drawbridge/keras-mmoe/master/data/census-income.test.gz [following]
# --2021-11-06 21:26:12--  https://raw.githubusercontent.com/drawbridge/keras-mmoe/master/data/census-income.test.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 416 Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.

# %% [markdown]
# # MMoE Setup

# %%
"""
Multi-gate Mixture-of-Experts model implementation.

Copyright (c) 2018 Drawbridge, Inc
Licensed under the MIT License (see LICENSE for details)
Written by Alvin Deng
"""

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras import activations, initializers, regularizers, constraints
from tensorflow.keras.layers import Layer, InputSpec


class MMoE(Layer):
    """
    Multi-gate Mixture-of-Experts model.
    """

    def __init__(self,
                 units,
                 num_experts,
                 num_tasks,
                 use_expert_bias=True,
                 use_gate_bias=True,
                 expert_activation='relu',
                 gate_activation='softmax',
                 expert_bias_initializer='zeros',
                 gate_bias_initializer='zeros',
                 expert_bias_regularizer=None,
                 gate_bias_regularizer=None,
                 expert_bias_constraint=None,
                 gate_bias_constraint=None,
                 expert_kernel_initializer='VarianceScaling',
                 gate_kernel_initializer='VarianceScaling',
                 expert_kernel_regularizer=None,
                 gate_kernel_regularizer=None,
                 expert_kernel_constraint=None,
                 gate_kernel_constraint=None,
                 activity_regularizer=None,
                 **kwargs):
        """
         Method for instantiating MMoE layer.

        :param units: Number of hidden units
        :param num_experts: Number of experts
        :param num_tasks: Number of tasks
        :param use_expert_bias: Boolean to indicate the usage of bias in the expert weights
        :param use_gate_bias: Boolean to indicate the usage of bias in the gate weights
        :param expert_activation: Activation function of the expert weights
        :param gate_activation: Activation function of the gate weights
        :param expert_bias_initializer: Initializer for the expert bias
        :param gate_bias_initializer: Initializer for the gate bias
        :param expert_bias_regularizer: Regularizer for the expert bias
        :param gate_bias_regularizer: Regularizer for the gate bias
        :param expert_bias_constraint: Constraint for the expert bias
        :param gate_bias_constraint: Constraint for the gate bias
        :param expert_kernel_initializer: Initializer for the expert weights
        :param gate_kernel_initializer: Initializer for the gate weights
        :param expert_kernel_regularizer: Regularizer for the expert weights
        :param gate_kernel_regularizer: Regularizer for the gate weights
        :param expert_kernel_constraint: Constraint for the expert weights
        :param gate_kernel_constraint: Constraint for the gate weights
        :param activity_regularizer: Regularizer for the activity
        :param kwargs: Additional keyword arguments for the Layer class
        """
        # Hidden nodes parameter
        self.units = units
        self.num_experts = num_experts
        self.num_tasks = num_tasks

        # Weight parameter
        self.expert_kernels = None
        self.gate_kernels = None
        self.expert_kernel_initializer = initializers.get(expert_kernel_initializer)
        self.gate_kernel_initializer = initializers.get(gate_kernel_initializer)
        self.expert_kernel_regularizer = regularizers.get(expert_kernel_regularizer)
        self.gate_kernel_regularizer = regularizers.get(gate_kernel_regularizer)
        self.expert_kernel_constraint = constraints.get(expert_kernel_constraint)
        self.gate_kernel_constraint = constraints.get(gate_kernel_constraint)

        # Activation parameter
        self.expert_activation = activations.get(expert_activation)
        self.gate_activation = activations.get(gate_activation)

        # Bias parameter
        self.expert_bias = None
        self.gate_bias = None
        self.use_expert_bias = use_expert_bias
        self.use_gate_bias = use_gate_bias
        self.expert_bias_initializer = initializers.get(expert_bias_initializer)
        self.gate_bias_initializer = initializers.get(gate_bias_initializer)
        self.expert_bias_regularizer = regularizers.get(expert_bias_regularizer)
        self.gate_bias_regularizer = regularizers.get(gate_bias_regularizer)
        self.expert_bias_constraint = constraints.get(expert_bias_constraint)
        self.gate_bias_constraint = constraints.get(gate_bias_constraint)

        # Activity parameter
        self.activity_regularizer = regularizers.get(activity_regularizer)

        # Keras parameter
        self.input_spec = InputSpec(min_ndim=2)
        self.supports_masking = True

        super(MMoE, self).__init__(**kwargs)

    def build(self, input_shape):
        """
        Method for creating the layer weights.

        :param input_shape: Keras tensor (future input to layer)
                            or list/tuple of Keras tensors to reference
                            for weight shape computations
        """
        assert input_shape is not None and len(input_shape) >= 2

        input_dimension = input_shape[-1]

        # Initialize expert weights (number of input features * number of units per expert * number of experts)
        self.expert_kernels = self.add_weight(
            name='expert_kernel',
            shape=(input_dimension, self.units, self.num_experts),
            initializer=self.expert_kernel_initializer,
            regularizer=self.expert_kernel_regularizer,
            constraint=self.expert_kernel_constraint,
        )

        # Initialize expert bias (number of units per expert * number of experts)
        if self.use_expert_bias:
            self.expert_bias = self.add_weight(
                name='expert_bias',
                shape=(self.units, self.num_experts),
                initializer=self.expert_bias_initializer,
                regularizer=self.expert_bias_regularizer,
                constraint=self.expert_bias_constraint,
            )

        # Initialize gate weights (number of input features * number of experts * number of tasks)
        self.gate_kernels = [self.add_weight(
            name='gate_kernel_task_{}'.format(i),
            shape=(input_dimension, self.num_experts),
            initializer=self.gate_kernel_initializer,
            regularizer=self.gate_kernel_regularizer,
            constraint=self.gate_kernel_constraint
        ) for i in range(self.num_tasks)]

        # Initialize gate bias (number of experts * number of tasks)
        if self.use_gate_bias:
            self.gate_bias = [self.add_weight(
                name='gate_bias_task_{}'.format(i),
                shape=(self.num_experts,),
                initializer=self.gate_bias_initializer,
                regularizer=self.gate_bias_regularizer,
                constraint=self.gate_bias_constraint
            ) for i in range(self.num_tasks)]

        self.input_spec = InputSpec(min_ndim=2, axes={-1: input_dimension})

        super(MMoE, self).build(input_shape)

    def call(self, inputs, **kwargs):
        """
        Method for the forward function of the layer.

        :param inputs: Input tensor
        :param kwargs: Additional keyword arguments for the base method
        :return: A tensor
        """
        gate_outputs = []
        final_outputs = []

        # f_{i}(x) = activation(W_{i} * x + b), where activation is ReLU according to the paper
        expert_outputs = tf.tensordot(a=inputs, b=self.expert_kernels, axes=1)
        # Add the bias term to the expert weights if necessary
        if self.use_expert_bias:
            expert_outputs = K.bias_add(x=expert_outputs, bias=self.expert_bias)
        expert_outputs = self.expert_activation(expert_outputs)

        # g^{k}(x) = activation(W_{gk} * x + b), where activation is softmax according to the paper
        for index, gate_kernel in enumerate(self.gate_kernels):
            gate_output = K.dot(x=inputs, y=gate_kernel)
            # Add the bias term to the gate weights if necessary
            if self.use_gate_bias:
                gate_output = K.bias_add(x=gate_output, bias=self.gate_bias[index])
            gate_output = self.gate_activation(gate_output)
            gate_outputs.append(gate_output)

        # f^{k}(x) = sum_{i=1}^{n}(g^{k}(x)_{i} * f_{i}(x))
        for gate_output in gate_outputs:
            expanded_gate_output = K.expand_dims(gate_output, axis=1)
            weighted_expert_output = expert_outputs * K.repeat_elements(expanded_gate_output, self.units, axis=1)
            final_outputs.append(K.sum(weighted_expert_output, axis=2))

        return final_outputs

    def compute_output_shape(self, input_shape):
        """
        Method for computing the output shape of the MMoE layer.

        :param input_shape: Shape tuple (tuple of integers)
        :return: List of input shape tuple where the size of the list is equal to the number of tasks
        """
        assert input_shape is not None and len(input_shape) >= 2

        output_shape = list(input_shape)
        output_shape[-1] = self.units
        output_shape = tuple(output_shape)

        return [output_shape for _ in range(self.num_tasks)]

    def get_config(self):
        """
        Method for returning the configuration of the MMoE layer.

        :return: Config dictionary
        """
        config = {
            'units': self.units,
            'num_experts': self.num_experts,
            'num_tasks': self.num_tasks,
            'use_expert_bias': self.use_expert_bias,
            'use_gate_bias': self.use_gate_bias,
            'expert_activation': activations.serialize(self.expert_activation),
            'gate_activation': activations.serialize(self.gate_activation),
            'expert_bias_initializer': initializers.serialize(self.expert_bias_initializer),
            'gate_bias_initializer': initializers.serialize(self.gate_bias_initializer),
            'expert_bias_regularizer': regularizers.serialize(self.expert_bias_regularizer),
            'gate_bias_regularizer': regularizers.serialize(self.gate_bias_regularizer),
            'expert_bias_constraint': constraints.serialize(self.expert_bias_constraint),
            'gate_bias_constraint': constraints.serialize(self.gate_bias_constraint),
            'expert_kernel_initializer': initializers.serialize(self.expert_kernel_initializer),
            'gate_kernel_initializer': initializers.serialize(self.gate_kernel_initializer),
            'expert_kernel_regularizer': regularizers.serialize(self.expert_kernel_regularizer),
            'gate_kernel_regularizer': regularizers.serialize(self.gate_kernel_regularizer),
            'expert_kernel_constraint': constraints.serialize(self.expert_kernel_constraint),
            'gate_kernel_constraint': constraints.serialize(self.gate_kernel_constraint),
            'activity_regularizer': regularizers.serialize(self.activity_regularizer)
        }
        base_config = super(MMoE, self).get_config()

        return dict(list(base_config.items()) + list(config.items()))

# %% [markdown]
# # Build and Run Sample 1 (titanic)

# %%
# """
# Multi-gate Mixture-of-Experts demo with census income data.

# Copyright (c) 2018 Drawbridge, Inc
# Licensed under the MIT License (see LICENSE for details)
# Written by Alvin Deng
# """

# import random

# import pandas as pd
# import numpy as np
# import tensorflow as tf
# from tensorflow.keras import backend as K
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.initializers import VarianceScaling
# from tensorflow.keras.layers import Input, Dense
# from tensorflow.keras.models import Model
# from tensorflow.keras.utils import to_categorical
# from tensorflow.keras.callbacks import Callback
# from sklearn.metrics import roc_auc_score

# SEED = 1

# # Fix numpy seed for reproducibility
# np.random.seed(SEED)

# # Fix random seed for reproducibility
# random.seed(SEED)

# # Fix TensorFlow graph-level seed for reproducibility
# tf.random.set_seed(SEED)

# # Simple callback to print out ROC-AUC
# class ROCCallback(Callback):
#     def __init__(self, training_data, validation_data, test_data):
#         self.train_X = training_data[0]
#         self.train_Y = training_data[1]
#         self.validation_X = validation_data[0]
#         self.validation_Y = validation_data[1]
#         self.test_X = test_data[0]
#         self.test_Y = test_data[1]

#     def on_train_begin(self, logs={}):
#         return

#     def on_train_end(self, logs={}):
#         return

#     def on_epoch_begin(self, epoch, logs={}):
#         return

#     def on_epoch_end(self, epoch, logs={}):
#         train_prediction = self.model.predict(self.train_X)
#         validation_prediction = self.model.predict(self.validation_X)
#         test_prediction = self.model.predict(self.test_X)

#         # Iterate through each task and output their ROC-AUC across different datasets
#         for index, output_name in enumerate(self.model.output_names):
#             train_roc_auc = roc_auc_score(self.train_Y[index], train_prediction[index])
#             validation_roc_auc = roc_auc_score(self.validation_Y[index], validation_prediction[index])
#             test_roc_auc = roc_auc_score(self.test_Y[index], test_prediction[index])
#             print(
#                 'ROC-AUC-{}-Train: {} ROC-AUC-{}-Validation: {} ROC-AUC-{}-Test: {}'.format(
#                     output_name, round(train_roc_auc, 4),
#                     output_name, round(validation_roc_auc, 4),
#                     output_name, round(test_roc_auc, 4)
#                 )
#             )

#         return

#     def on_batch_begin(self, batch, logs={}):
#         return

#     def on_batch_end(self, batch, logs={}):
#         return


# def data_preparation():
#     # The column names are from
#     # https://www2.1010data.com/documentationcenter/prod/Tutorials/MachineLearningExamples/CensusIncomeDataSet.html

#     column_names = ['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare']

#     from numpy.random import RandomState
#     import pandas as pd

#     df = pd.read_csv('train.csv')
#     df.drop(['Name', 'Ticket'], axis=1)
#     rng = RandomState()

#     train_df = df.sample(frac=0.7, random_state=rng)
#     other_df = df.loc[~df.index.isin(train_df.index)]

#     # Load the dataset in Pandas
#     # train_df = pd.read_csv(
#     #     'data/census-income.data.gz',
#     #     delimiter=',',
#     #     header=None,
#     #     index_col=None,
#     #     names=column_names
#     # )
#     # other_df = pd.read_csv(
#     #     'data/census-income.test.gz',
#     #     delimiter=',',
#     #     header=None,
#     #     index_col=None,
#     #     names=column_names
#     # )

#     # First group of tasks according to the paper
#     label_columns = ['Survived']

#     # One-hot encoding categorical columns
#     train_raw_labels = train_df[label_columns]
#     other_raw_labels = other_df[label_columns]

#     # Filling the missing column in the other set
#     # transformed_other['det_hh_fam_stat_ Grandchild <18 ever marr not in subfamily'] = 0

#     # One-hot encoding categorical labels
#     train_Survived = to_categorical((train_raw_labels.Survived).astype(int), num_classes=2)
#     # train_marital = to_categorical((train_raw_labels.marital_stat == ' Never married').astype(int), num_classes=2)
#     other_Survived = to_categorical((other_raw_labels.Survived).astype(int), num_classes=2)
#     # other_marital = to_categorical((other_raw_labels.marital_stat == ' Never married').astype(int), num_classes=2)

#     dict_outputs = {
#         'Survived': train_raw_labels.shape[1],
#     }
#     dict_train_labels = {
#         'Survived': train_raw_labels,
#     }
#     dict_other_labels = {
#         'Survived': other_raw_labels,
#     }
#     print (len(other_Survived))
#     output_info = [(dict_outputs[key], key) for key in sorted(dict_outputs.keys())]

#     # Split the other dataset into 1:1 validation to test according to the paper
#     validation_indices = other_raw_labels.sample(frac=0.5, replace=False, random_state=SEED).index
#     test_indices = list(set(other_raw_labels.index) - set(validation_indices))
#     print(other_raw_labels)
#     print(validation_indices)
#     validation_data = other_raw_labels.iloc[validation_indices]
#     validation_label = [dict_other_labels[key][validation_indices] for key in sorted(dict_other_labels.keys())]
#     test_data = other_raw_labels.iloc[test_indices]
#     test_label = [dict_other_labels[key][test_indices] for key in sorted(dict_other_labels.keys())]
#     train_data = transformed_train
#     train_label = [dict_train_labels[key] for key in sorted(dict_train_labels.keys())]

#     return train_data, train_label, validation_data, validation_label, test_data, test_label, output_info


# def main():
#     # Load the data
#     train_data, train_label, validation_data, validation_label, test_data, test_label, output_info = data_preparation()
#     num_features = train_data.shape[1]

#     print('Training data shape = {}'.format(train_data.shape))
#     print('Validation data shape = {}'.format(validation_data.shape))
#     print('Test data shape = {}'.format(test_data.shape))

#     # Set up the input layer
#     input_layer = Input(shape=(num_features,))

#     # Set up MMoE layer
#     mmoe_layers = MMoE(
#         units=4,
#         num_experts=8,
#         num_tasks=2
#     )(input_layer)

#     output_layers = []

#     # Build tower layer from MMoE layer
#     for index, task_layer in enumerate(mmoe_layers):
#         tower_layer = Dense(
#             units=8,
#             activation='relu',
#             kernel_initializer=VarianceScaling())(task_layer)
#         output_layer = Dense(
#             units=output_info[index][0],
#             name=output_info[index][1],
#             activation='softmax',
#             kernel_initializer=VarianceScaling())(tower_layer)
#         output_layers.append(output_layer)

#     # Compile model
#     model = Model(inputs=[input_layer], outputs=output_layers)
#     adam_optimizer = Adam()
#     model.compile(
#         loss={'income': 'binary_crossentropy', 'marital': 'binary_crossentropy'},
#         optimizer=adam_optimizer,
#         metrics=['accuracy']
#     )

#     # Print out model architecture summary
#     model.summary()

#     # Train the model
#     model.fit(
#         x=train_data,
#         y=train_label,
#         validation_data=(validation_data, validation_label),
#         callbacks=[
#             ROCCallback(
#                 training_data=(train_data, train_label),
#                 validation_data=(validation_data, validation_label),
#                 test_data=(test_data, test_label)
#             )
#         ],
#         epochs=100
#     )


# if __name__ == '__main__':
#     main()

# %% [markdown]
# # Build and Run Sample 1 (original)

# %%
"""
Multi-gate Mixture-of-Experts demo with census income data.

Copyright (c) 2018 Drawbridge, Inc
Licensed under the MIT License (see LICENSE for details)
Written by Alvin Deng
"""

import random

import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import VarianceScaling
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import roc_auc_score

SEED = 1

# Fix numpy seed for reproducibility
np.random.seed(SEED)

# Fix random seed for reproducibility
random.seed(SEED)

# Fix TensorFlow graph-level seed for reproducibility
tf.random.set_seed(SEED)

# Simple callback to print out ROC-AUC
class ROCCallback(Callback):
    def __init__(self, training_data, validation_data, test_data):
        self.train_X = training_data[0]
        self.train_Y = training_data[1]
        self.validation_X = validation_data[0]
        self.validation_Y = validation_data[1]
        self.test_X = test_data[0]
        self.test_Y = test_data[1]

    def on_train_begin(self, logs={}):
        return

    def on_train_end(self, logs={}):
        return

    def on_epoch_begin(self, epoch, logs={}):
        return

    def on_epoch_end(self, epoch, logs={}):
        train_prediction = self.model.predict(self.train_X)
        validation_prediction = self.model.predict(self.validation_X)
        test_prediction = self.model.predict(self.test_X)

        # Iterate through each task and output their ROC-AUC across different datasets
        for index, output_name in enumerate(self.model.output_names):
            train_roc_auc = roc_auc_score(self.train_Y[index], train_prediction[index])
            validation_roc_auc = roc_auc_score(self.validation_Y[index], validation_prediction[index])
            test_roc_auc = roc_auc_score(self.test_Y[index], test_prediction[index])
            print(
                'ROC-AUC-{}-Train: {} ROC-AUC-{}-Validation: {} ROC-AUC-{}-Test: {}'.format(
                    output_name, round(train_roc_auc, 4),
                    output_name, round(validation_roc_auc, 4),
                    output_name, round(test_roc_auc, 4)
                )
            )

        return

    def on_batch_begin(self, batch, logs={}):
        return

    def on_batch_end(self, batch, logs={}):
        return


def data_preparation():
    # The column names are from
    # https://www2.1010data.com/documentationcenter/prod/Tutorials/MachineLearningExamples/CensusIncomeDataSet.html
    column_names = ['age', 'class_worker', 'det_ind_code', 'det_occ_code', 'education', 'wage_per_hour', 'hs_college',
                    'marital_stat', 'major_ind_code', 'major_occ_code', 'race', 'hisp_origin', 'sex', 'union_member',
                    'unemp_reason', 'full_or_part_emp', 'capital_gains', 'capital_losses', 'stock_dividends',
                    'tax_filer_stat', 'region_prev_res', 'state_prev_res', 'det_hh_fam_stat', 'det_hh_summ',
                    'instance_weight', 'mig_chg_msa', 'mig_chg_reg', 'mig_move_reg', 'mig_same', 'mig_prev_sunbelt',
                    'num_emp', 'fam_under_18', 'country_father', 'country_mother', 'country_self', 'citizenship',
                    'own_or_self', 'vet_question', 'vet_benefits', 'weeks_worked', 'year', 'income_50k']

    # Load the dataset in Pandas
    train_df = pd.read_csv(
        'data/census-income.data.gz',
        delimiter=',',
        header=None,
        index_col=None,
        names=column_names
    )
    other_df = pd.read_csv(
        'data/census-income.test.gz',
        delimiter=',',
        header=None,
        index_col=None,
        names=column_names
    )

    # First group of tasks according to the paper
    label_columns = ['income_50k', 'marital_stat']

    # One-hot encoding categorical columns
    categorical_columns = ['class_worker', 'det_ind_code', 'det_occ_code', 'education', 'hs_college', 'major_ind_code',
                           'major_occ_code', 'race', 'hisp_origin', 'sex', 'union_member', 'unemp_reason',
                           'full_or_part_emp', 'tax_filer_stat', 'region_prev_res', 'state_prev_res', 'det_hh_fam_stat',
                           'det_hh_summ', 'mig_chg_msa', 'mig_chg_reg', 'mig_move_reg', 'mig_same', 'mig_prev_sunbelt',
                           'fam_under_18', 'country_father', 'country_mother', 'country_self', 'citizenship',
                           'vet_question']
    train_raw_labels = train_df[label_columns]
    other_raw_labels = other_df[label_columns]
    transformed_train = pd.get_dummies(train_df.drop(label_columns, axis=1), columns=categorical_columns)
    transformed_other = pd.get_dummies(other_df.drop(label_columns, axis=1), columns=categorical_columns)

    # Filling the missing column in the other set
    transformed_other['det_hh_fam_stat_ Grandchild <18 ever marr not in subfamily'] = 0

    # One-hot encoding categorical labels
    train_income = to_categorical((train_raw_labels.income_50k == ' 50000+.').astype(int), num_classes=2)
    train_marital = to_categorical((train_raw_labels.marital_stat == ' Never married').astype(int), num_classes=2)
    other_income = to_categorical((other_raw_labels.income_50k == ' 50000+.').astype(int), num_classes=2)
    other_marital = to_categorical((other_raw_labels.marital_stat == ' Never married').astype(int), num_classes=2)

    dict_outputs = {
        'income': train_income.shape[1],
        'marital': train_marital.shape[1]
    }
    dict_train_labels = {
        'income': train_income,
        'marital': train_marital
    }
    dict_other_labels = {
        'income': other_income,
        'marital': other_marital
    }
    output_info = [(dict_outputs[key], key) for key in sorted(dict_outputs.keys())]

    # Split the other dataset into 1:1 validation to test according to the paper
    validation_indices = transformed_other.sample(frac=0.5, replace=False, random_state=SEED).index
    test_indices = list(set(transformed_other.index) - set(validation_indices))
    validation_data = transformed_other.iloc[validation_indices]
    validation_label = [dict_other_labels[key][validation_indices] for key in sorted(dict_other_labels.keys())]
    test_data = transformed_other.iloc[test_indices]
    test_label = [dict_other_labels[key][test_indices] for key in sorted(dict_other_labels.keys())]
    train_data = transformed_train
    train_label = [dict_train_labels[key] for key in sorted(dict_train_labels.keys())]

    return train_data, train_label, validation_data, validation_label, test_data, test_label, output_info


def main():
    # Load the data
    train_data, train_label, validation_data, validation_label, test_data, test_label, output_info = data_preparation()
    num_features = train_data.shape[1]

    print('Training data shape = {}'.format(train_data.shape))
    print('Validation data shape = {}'.format(validation_data.shape))
    print('Test data shape = {}'.format(test_data.shape))

    # Set up the input layer
    input_layer = Input(shape=(num_features,))

    # Set up MMoE layer
    mmoe_layers = MMoE(
        units=4,
        num_experts=8,
        num_tasks=2
    )(input_layer)

    output_layers = []

    # Build tower layer from MMoE layer
    for index, task_layer in enumerate(mmoe_layers):
        tower_layer = Dense(
            units=8,
            activation='relu',
            kernel_initializer=VarianceScaling())(task_layer)
        output_layer = Dense(
            units=output_info[index][0],
            name=output_info[index][1],
            activation='softmax',
            kernel_initializer=VarianceScaling())(tower_layer)
        output_layers.append(output_layer)

    # Compile model
    model = Model(inputs=[input_layer], outputs=output_layers)
    adam_optimizer = Adam()
    model.compile(
        loss={'income': 'binary_crossentropy', 'marital': 'binary_crossentropy'},
        optimizer=adam_optimizer,
        metrics=['accuracy']
    )

    # Print out model architecture summary
    model.summary()

    # Train the model
    model.fit(
        x=train_data,
        y=train_label,
        validation_data=(validation_data, validation_label),
        callbacks=[
            ROCCallback(
                training_data=(train_data, train_label),
                validation_data=(validation_data, validation_label),
                test_data=(test_data, test_label)
            )
        ],
        epochs=100
    )


if __name__ == '__main__':
    main()
# Out:
# Training data shape = (199523, 499)
# Validation data shape = (49881, 499)
# Test data shape = (49881, 499)
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 499)]        0
# __________________________________________________________________________________________________
# m_mo_e (MMoE)                   [(None, 4), (None, 4 24000       input_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 8)            40          m_mo_e[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 8)            40          m_mo_e[0][1]
# __________________________________________________________________________________________________
# income (Dense)                  (None, 2)            18          dense[0][0]
# __________________________________________________________________________________________________
# marital (Dense)                 (None, 2)            18          dense_1[0][0]
# ==================================================================================================
# Total params: 24,116
# Trainable params: 24,116
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 6236/6236 [==============================] - 19s 3ms/step - loss: 0.4771 - income_loss: 0.1835 - marital_loss: 0.2936 - income_accuracy: 0.9378 - marital_accuracy: 0.8888 - val_loss: 0.3661 - val_income_loss: 0.1647 - val_marital_loss: 0.2014 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.9313
# ROC-AUC-income-Train: 0.9139 ROC-AUC-income-Validation: 0.9147 ROC-AUC-income-Test: 0.9137
# ROC-AUC-marital-Train: 0.968 ROC-AUC-marital-Validation: 0.958 ROC-AUC-marital-Test: 0.9595
# Epoch 2/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.3257 - income_loss: 0.1532 - marital_loss: 0.1725 - income_accuracy: 0.9379 - marital_accuracy: 0.9391 - val_loss: 0.3671 - val_income_loss: 0.1515 - val_marital_loss: 0.2157 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.9231
# ROC-AUC-income-Train: 0.917 ROC-AUC-income-Validation: 0.9146 ROC-AUC-income-Test: 0.9145
# ROC-AUC-marital-Train: 0.9746 ROC-AUC-marital-Validation: 0.9614 ROC-AUC-marital-Test: 0.9619
# Epoch 3/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2957 - income_loss: 0.1511 - marital_loss: 0.1446 - income_accuracy: 0.9379 - marital_accuracy: 0.9467 - val_loss: 0.3668 - val_income_loss: 0.1644 - val_marital_loss: 0.2023 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.9258
# ROC-AUC-income-Train: 0.9183 ROC-AUC-income-Validation: 0.9152 ROC-AUC-income-Test: 0.9149
# ROC-AUC-marital-Train: 0.979 ROC-AUC-marital-Validation: 0.9658 ROC-AUC-marital-Test: 0.9652
# Epoch 4/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2862 - income_loss: 0.1459 - marital_loss: 0.1403 - income_accuracy: 0.9379 - marital_accuracy: 0.9479 - val_loss: 0.3860 - val_income_loss: 0.1490 - val_marital_loss: 0.2371 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.9094
# ROC-AUC-income-Train: 0.9199 ROC-AUC-income-Validation: 0.9182 ROC-AUC-income-Test: 0.9185
# ROC-AUC-marital-Train: 0.9841 ROC-AUC-marital-Validation: 0.9699 ROC-AUC-marital-Test: 0.9699
# Epoch 5/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2816 - income_loss: 0.1456 - marital_loss: 0.1360 - income_accuracy: 0.9379 - marital_accuracy: 0.9493 - val_loss: 0.3918 - val_income_loss: 0.1683 - val_marital_loss: 0.2235 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.9158
# ROC-AUC-income-Train: 0.9235 ROC-AUC-income-Validation: 0.9194 ROC-AUC-income-Test: 0.9184
# ROC-AUC-marital-Train: 0.982 ROC-AUC-marital-Validation: 0.9674 ROC-AUC-marital-Test: 0.9672
# Epoch 6/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2771 - income_loss: 0.1432 - marital_loss: 0.1339 - income_accuracy: 0.9379 - marital_accuracy: 0.9498 - val_loss: 0.4545 - val_income_loss: 0.1725 - val_marital_loss: 0.2820 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.9056
# ROC-AUC-income-Train: 0.926 ROC-AUC-income-Validation: 0.9215 ROC-AUC-income-Test: 0.9215
# ROC-AUC-marital-Train: 0.9829 ROC-AUC-marital-Validation: 0.9648 ROC-AUC-marital-Test: 0.9646
# Epoch 7/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2768 - income_loss: 0.1418 - marital_loss: 0.1350 - income_accuracy: 0.9379 - marital_accuracy: 0.9503 - val_loss: 0.3990 - val_income_loss: 0.1673 - val_marital_loss: 0.2317 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.9107
# ROC-AUC-income-Train: 0.9266 ROC-AUC-income-Validation: 0.9237 ROC-AUC-income-Test: 0.923
# ROC-AUC-marital-Train: 0.9859 ROC-AUC-marital-Validation: 0.9696 ROC-AUC-marital-Test: 0.9691
# Epoch 8/100
# 6236/6236 [==============================] - 17s 3ms/step - loss: 0.2706 - income_loss: 0.1421 - marital_loss: 0.1285 - income_accuracy: 0.9379 - marital_accuracy: 0.9511 - val_loss: 0.4183 - val_income_loss: 0.1769 - val_marital_loss: 0.2414 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.9090
# ROC-AUC-income-Train: 0.9369 ROC-AUC-income-Validation: 0.9342 ROC-AUC-income-Test: 0.9333
# ROC-AUC-marital-Train: 0.9839 ROC-AUC-marital-Validation: 0.964 ROC-AUC-marital-Test: 0.9636
# Epoch 9/100
# 6236/6236 [==============================] - 17s 3ms/step - loss: 0.2658 - income_loss: 0.1410 - marital_loss: 0.1248 - income_accuracy: 0.9379 - marital_accuracy: 0.9522 - val_loss: 0.4420 - val_income_loss: 0.1590 - val_marital_loss: 0.2830 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.8935
# ROC-AUC-income-Train: 0.9292 ROC-AUC-income-Validation: 0.9254 ROC-AUC-income-Test: 0.9245
# ROC-AUC-marital-Train: 0.9868 ROC-AUC-marital-Validation: 0.968 ROC-AUC-marital-Test: 0.9676
# Epoch 10/100
# 6236/6236 [==============================] - 17s 3ms/step - loss: 0.2663 - income_loss: 0.1399 - marital_loss: 0.1264 - income_accuracy: 0.9381 - marital_accuracy: 0.9519 - val_loss: 0.4029 - val_income_loss: 0.1658 - val_marital_loss: 0.2370 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.9114
# ROC-AUC-income-Train: 0.927 ROC-AUC-income-Validation: 0.9238 ROC-AUC-income-Test: 0.9218
# ROC-AUC-marital-Train: 0.9839 ROC-AUC-marital-Validation: 0.9661 ROC-AUC-marital-Test: 0.9659
# Epoch 11/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2676 - income_loss: 0.1406 - marital_loss: 0.1270 - income_accuracy: 0.9380 - marital_accuracy: 0.9518 - val_loss: 0.4124 - val_income_loss: 0.1710 - val_marital_loss: 0.2414 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.9094
# ROC-AUC-income-Train: 0.9286 ROC-AUC-income-Validation: 0.9238 ROC-AUC-income-Test: 0.9241
# ROC-AUC-marital-Train: 0.9853 ROC-AUC-marital-Validation: 0.9656 ROC-AUC-marital-Test: 0.9653
# Epoch 12/100
# 6236/6236 [==============================] - 16s 3ms/step - loss: 0.2658 - income_loss: 0.1397 - marital_loss: 0.1261 - income_accuracy: 0.9379 - marital_accuracy: 0.9523 - val_loss: 0.4738 - val_income_loss: 0.2119 - val_marital_loss: 0.2619 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.9003
# ROC-AUC-income-Train: 0.9311 ROC-AUC-income-Validation: 0.9265 ROC-AUC-income-Test: 0.9254
# ROC-AUC-marital-Train: 0.9867 ROC-AUC-marital-Validation: 0.9649 ROC-AUC-marital-Test: 0.9647
# Epoch 13/100
# 6236/6236 [==============================] - 17s 3ms/step - loss: 0.2617 - income_loss: 0.1371 - marital_loss: 0.1246 - income_accuracy: 0.9413 - marital_accuracy: 0.9524 - val_loss: 0.4099 - val_income_loss: 0.1600 - val_marital_loss: 0.2499 - val_income_accuracy: 0.9390 - val_marital_accuracy: 0.9047
# ROC-AUC-income-Train: 0.9319 ROC-AUC-income-Validation: 0.9291 ROC-AUC-income-Test: 0.9278
# ROC-AUC-marital-Train: 0.9871 ROC-AUC-marital-Validation: 0.9665 ROC-AUC-marital-Test: 0.966
# Epoch 14/100
# 6236/6236 [==============================] - 17s 3ms/step - loss: 0.2610 - income_loss: 0.1373 - marital_loss: 0.1237 - income_accuracy: 0.9404 - marital_accuracy: 0.9532 - val_loss: 0.4334 - val_income_loss: 0.1796 - val_marital_loss: 0.2538 - val_income_accuracy: 0.9368 - val_marital_accuracy: 0.9049
# ROC-AUC-income-Train: 0.933 ROC-AUC-income-Validation: 0.9289 ROC-AUC-income-Test: 0.9274
# ROC-AUC-marital-Train: 0.9861 ROC-AUC-marital-Validation: 0.9641 ROC-AUC-marital-Test: 0.9638
# Epoch 15/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2606 - income_loss: 0.1386 - marital_loss: 0.1221 - income_accuracy: 0.9418 - marital_accuracy: 0.9534 - val_loss: 0.4489 - val_income_loss: 0.1859 - val_marital_loss: 0.2630 - val_income_accuracy: 0.9373 - val_marital_accuracy: 0.9009
# ROC-AUC-income-Train: 0.935 ROC-AUC-income-Validation: 0.9303 ROC-AUC-income-Test: 0.9286
# ROC-AUC-marital-Train: 0.9862 ROC-AUC-marital-Validation: 0.9639 ROC-AUC-marital-Test: 0.9635
# Epoch 16/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2576 - income_loss: 0.1351 - marital_loss: 0.1226 - income_accuracy: 0.9445 - marital_accuracy: 0.9534 - val_loss: 0.4450 - val_income_loss: 0.1914 - val_marital_loss: 0.2536 - val_income_accuracy: 0.9419 - val_marital_accuracy: 0.9047
# ROC-AUC-income-Train: 0.9342 ROC-AUC-income-Validation: 0.9285 ROC-AUC-income-Test: 0.9286
# ROC-AUC-marital-Train: 0.9854 ROC-AUC-marital-Validation: 0.9623 ROC-AUC-marital-Test: 0.9619
# Epoch 17/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2555 - income_loss: 0.1337 - marital_loss: 0.1217 - income_accuracy: 0.9448 - marital_accuracy: 0.9537 - val_loss: 0.4971 - val_income_loss: 0.1549 - val_marital_loss: 0.3421 - val_income_accuracy: 0.9377 - val_marital_accuracy: 0.8700
# ROC-AUC-income-Train: 0.9281 ROC-AUC-income-Validation: 0.9248 ROC-AUC-income-Test: 0.9244
# ROC-AUC-marital-Train: 0.9872 ROC-AUC-marital-Validation: 0.9635 ROC-AUC-marital-Test: 0.9631
# Epoch 18/100
# 6236/6236 [==============================] - 17s 3ms/step - loss: 0.2623 - income_loss: 0.1344 - marital_loss: 0.1279 - income_accuracy: 0.9436 - marital_accuracy: 0.9537 - val_loss: 0.4491 - val_income_loss: 0.1632 - val_marital_loss: 0.2859 - val_income_accuracy: 0.9443 - val_marital_accuracy: 0.8909
# ROC-AUC-income-Train: 0.9383 ROC-AUC-income-Validation: 0.9334 ROC-AUC-income-Test: 0.9325
# ROC-AUC-marital-Train: 0.9858 ROC-AUC-marital-Validation: 0.9619 ROC-AUC-marital-Test: 0.9614
# Epoch 19/100
# 6236/6236 [==============================] - 17s 3ms/step - loss: 0.2559 - income_loss: 0.1348 - marital_loss: 0.1211 - income_accuracy: 0.9449 - marital_accuracy: 0.9542 - val_loss: 0.4399 - val_income_loss: 0.1684 - val_marital_loss: 0.2715 - val_income_accuracy: 0.9402 - val_marital_accuracy: 0.8994
# ROC-AUC-income-Train: 0.9354 ROC-AUC-income-Validation: 0.9313 ROC-AUC-income-Test: 0.9301
# ROC-AUC-marital-Train: 0.9873 ROC-AUC-marital-Validation: 0.9611 ROC-AUC-marital-Test: 0.9606
# Epoch 20/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2522 - income_loss: 0.1349 - marital_loss: 0.1173 - income_accuracy: 0.9439 - marital_accuracy: 0.9544 - val_loss: 0.4465 - val_income_loss: 0.1924 - val_marital_loss: 0.2541 - val_income_accuracy: 0.9423 - val_marital_accuracy: 0.9018
# ROC-AUC-income-Train: 0.9381 ROC-AUC-income-Validation: 0.9336 ROC-AUC-income-Test: 0.9323
# ROC-AUC-marital-Train: 0.9888 ROC-AUC-marital-Validation: 0.9643 ROC-AUC-marital-Test: 0.9637
# Epoch 21/100
# 6236/6236 [==============================] - 17s 3ms/step - loss: 0.2517 - income_loss: 0.1348 - marital_loss: 0.1169 - income_accuracy: 0.9444 - marital_accuracy: 0.9542 - val_loss: 0.4630 - val_income_loss: 0.1628 - val_marital_loss: 0.3002 - val_income_accuracy: 0.9456 - val_marital_accuracy: 0.8828
# ROC-AUC-income-Train: 0.9424 ROC-AUC-income-Validation: 0.9387 ROC-AUC-income-Test: 0.9376
# ROC-AUC-marital-Train: 0.9892 ROC-AUC-marital-Validation: 0.9647 ROC-AUC-marital-Test: 0.964
# Epoch 22/100
# 6236/6236 [==============================] - 17s 3ms/step - loss: 0.2510 - income_loss: 0.1341 - marital_loss: 0.1169 - income_accuracy: 0.9450 - marital_accuracy: 0.9545 - val_loss: 0.4423 - val_income_loss: 0.1626 - val_marital_loss: 0.2797 - val_income_accuracy: 0.9461 - val_marital_accuracy: 0.8927
# ROC-AUC-income-Train: 0.9363 ROC-AUC-income-Validation: 0.9328 ROC-AUC-income-Test: 0.9318
# ROC-AUC-marital-Train: 0.9885 ROC-AUC-marital-Validation: 0.9648 ROC-AUC-marital-Test: 0.9646
# Epoch 23/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2509 - income_loss: 0.1343 - marital_loss: 0.1165 - income_accuracy: 0.9464 - marital_accuracy: 0.9543 - val_loss: 0.5157 - val_income_loss: 0.1855 - val_marital_loss: 0.3302 - val_income_accuracy: 0.9461 - val_marital_accuracy: 0.8690
# ROC-AUC-income-Train: 0.9428 ROC-AUC-income-Validation: 0.939 ROC-AUC-income-Test: 0.9377
# ROC-AUC-marital-Train: 0.9873 ROC-AUC-marital-Validation: 0.9632 ROC-AUC-marital-Test: 0.9624
# Epoch 24/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2506 - income_loss: 0.1337 - marital_loss: 0.1168 - income_accuracy: 0.9472 - marital_accuracy: 0.9545 - val_loss: 0.5126 - val_income_loss: 0.1947 - val_marital_loss: 0.3180 - val_income_accuracy: 0.9462 - val_marital_accuracy: 0.8716
# ROC-AUC-income-Train: 0.9424 ROC-AUC-income-Validation: 0.9379 ROC-AUC-income-Test: 0.9364
# ROC-AUC-marital-Train: 0.9911 ROC-AUC-marital-Validation: 0.9671 ROC-AUC-marital-Test: 0.9668
# Epoch 25/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2470 - income_loss: 0.1327 - marital_loss: 0.1143 - income_accuracy: 0.9486 - marital_accuracy: 0.9552 - val_loss: 0.5120 - val_income_loss: 0.1819 - val_marital_loss: 0.3301 - val_income_accuracy: 0.9447 - val_marital_accuracy: 0.8716
# ROC-AUC-income-Train: 0.9405 ROC-AUC-income-Validation: 0.9359 ROC-AUC-income-Test: 0.9346
# ROC-AUC-marital-Train: 0.9879 ROC-AUC-marital-Validation: 0.9638 ROC-AUC-marital-Test: 0.9634
# Epoch 26/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2481 - income_loss: 0.1331 - marital_loss: 0.1151 - income_accuracy: 0.9458 - marital_accuracy: 0.9548 - val_loss: 0.4746 - val_income_loss: 0.2014 - val_marital_loss: 0.2732 - val_income_accuracy: 0.9432 - val_marital_accuracy: 0.8932
# ROC-AUC-income-Train: 0.9287 ROC-AUC-income-Validation: 0.9218 ROC-AUC-income-Test: 0.9222
# ROC-AUC-marital-Train: 0.9895 ROC-AUC-marital-Validation: 0.9649 ROC-AUC-marital-Test: 0.9644
# Epoch 27/100
# 6236/6236 [==============================] - 17s 3ms/step - loss: 0.2454 - income_loss: 0.1341 - marital_loss: 0.1113 - income_accuracy: 0.9450 - marital_accuracy: 0.9555 - val_loss: 0.4889 - val_income_loss: 0.1857 - val_marital_loss: 0.3032 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.8847
# ROC-AUC-income-Train: 0.9348 ROC-AUC-income-Validation: 0.9289 ROC-AUC-income-Test: 0.9284
# ROC-AUC-marital-Train: 0.9894 ROC-AUC-marital-Validation: 0.9641 ROC-AUC-marital-Test: 0.964
# Epoch 28/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2453 - income_loss: 0.1326 - marital_loss: 0.1127 - income_accuracy: 0.9467 - marital_accuracy: 0.9556 - val_loss: 0.4497 - val_income_loss: 0.1797 - val_marital_loss: 0.2700 - val_income_accuracy: 0.9452 - val_marital_accuracy: 0.8960
# ROC-AUC-income-Train: 0.9428 ROC-AUC-income-Validation: 0.9384 ROC-AUC-income-Test: 0.9377
# ROC-AUC-marital-Train: 0.9894 ROC-AUC-marital-Validation: 0.9643 ROC-AUC-marital-Test: 0.964
# Epoch 29/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2473 - income_loss: 0.1324 - marital_loss: 0.1149 - income_accuracy: 0.9458 - marital_accuracy: 0.9553 - val_loss: 0.5063 - val_income_loss: 0.1970 - val_marital_loss: 0.3093 - val_income_accuracy: 0.9341 - val_marital_accuracy: 0.8791
# ROC-AUC-income-Train: 0.9288 ROC-AUC-income-Validation: 0.9217 ROC-AUC-income-Test: 0.9218
# ROC-AUC-marital-Train: 0.9917 ROC-AUC-marital-Validation: 0.9661 ROC-AUC-marital-Test: 0.9659
# Epoch 30/100
# 6236/6236 [==============================] - 17s 3ms/step - loss: 0.2467 - income_loss: 0.1331 - marital_loss: 0.1135 - income_accuracy: 0.9459 - marital_accuracy: 0.9556 - val_loss: 0.5321 - val_income_loss: 0.1923 - val_marital_loss: 0.3397 - val_income_accuracy: 0.9447 - val_marital_accuracy: 0.8633
# ROC-AUC-income-Train: 0.9392 ROC-AUC-income-Validation: 0.9343 ROC-AUC-income-Test: 0.9333
# ROC-AUC-marital-Train: 0.9902 ROC-AUC-marital-Validation: 0.9642 ROC-AUC-marital-Test: 0.964
# Epoch 31/100
# 6236/6236 [==============================] - 17s 3ms/step - loss: 0.2454 - income_loss: 0.1342 - marital_loss: 0.1111 - income_accuracy: 0.9474 - marital_accuracy: 0.9557 - val_loss: 0.5050 - val_income_loss: 0.1936 - val_marital_loss: 0.3114 - val_income_accuracy: 0.9431 - val_marital_accuracy: 0.8773
# ROC-AUC-income-Train: 0.9389 ROC-AUC-income-Validation: 0.9341 ROC-AUC-income-Test: 0.9318
# ROC-AUC-marital-Train: 0.9902 ROC-AUC-marital-Validation: 0.964 ROC-AUC-marital-Test: 0.9635
# Epoch 32/100
# 6236/6236 [==============================] - 17s 3ms/step - loss: 0.2436 - income_loss: 0.1329 - marital_loss: 0.1106 - income_accuracy: 0.9478 - marital_accuracy: 0.9555 - val_loss: 0.4649 - val_income_loss: 0.1904 - val_marital_loss: 0.2745 - val_income_accuracy: 0.9448 - val_marital_accuracy: 0.8947
# ROC-AUC-income-Train: 0.9434 ROC-AUC-income-Validation: 0.9379 ROC-AUC-income-Test: 0.9373
# ROC-AUC-marital-Train: 0.9883 ROC-AUC-marital-Validation: 0.9615 ROC-AUC-marital-Test: 0.9612
# Epoch 33/100
# 6236/6236 [==============================] - 19s 3ms/step - loss: 0.2414 - income_loss: 0.1312 - marital_loss: 0.1102 - income_accuracy: 0.9484 - marital_accuracy: 0.9557 - val_loss: 0.4939 - val_income_loss: 0.1725 - val_marital_loss: 0.3214 - val_income_accuracy: 0.9449 - val_marital_accuracy: 0.8723
# ROC-AUC-income-Train: 0.9404 ROC-AUC-income-Validation: 0.9352 ROC-AUC-income-Test: 0.9342
# ROC-AUC-marital-Train: 0.9912 ROC-AUC-marital-Validation: 0.9635 ROC-AUC-marital-Test: 0.9631
# Epoch 34/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2396 - income_loss: 0.1322 - marital_loss: 0.1074 - income_accuracy: 0.9486 - marital_accuracy: 0.9560 - val_loss: 0.5061 - val_income_loss: 0.1737 - val_marital_loss: 0.3325 - val_income_accuracy: 0.9459 - val_marital_accuracy: 0.8718
# ROC-AUC-income-Train: 0.9434 ROC-AUC-income-Validation: 0.9381 ROC-AUC-income-Test: 0.9375
# ROC-AUC-marital-Train: 0.989 ROC-AUC-marital-Validation: 0.9607 ROC-AUC-marital-Test: 0.9606
# Epoch 35/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2417 - income_loss: 0.1321 - marital_loss: 0.1097 - income_accuracy: 0.9488 - marital_accuracy: 0.9561 - val_loss: 0.5037 - val_income_loss: 0.1774 - val_marital_loss: 0.3262 - val_income_accuracy: 0.9463 - val_marital_accuracy: 0.8717
# ROC-AUC-income-Train: 0.9409 ROC-AUC-income-Validation: 0.9363 ROC-AUC-income-Test: 0.935
# ROC-AUC-marital-Train: 0.9898 ROC-AUC-marital-Validation: 0.9614 ROC-AUC-marital-Test: 0.961
# Epoch 36/100
# 6236/6236 [==============================] - 19s 3ms/step - loss: 0.2428 - income_loss: 0.1318 - marital_loss: 0.1110 - income_accuracy: 0.9480 - marital_accuracy: 0.9559 - val_loss: 0.5085 - val_income_loss: 0.1815 - val_marital_loss: 0.3270 - val_income_accuracy: 0.9456 - val_marital_accuracy: 0.8703
# ROC-AUC-income-Train: 0.9424 ROC-AUC-income-Validation: 0.9361 ROC-AUC-income-Test: 0.9354
# ROC-AUC-marital-Train: 0.9919 ROC-AUC-marital-Validation: 0.9632 ROC-AUC-marital-Test: 0.9629
# Epoch 37/100
# 6236/6236 [==============================] - 19s 3ms/step - loss: 0.2382 - income_loss: 0.1302 - marital_loss: 0.1080 - income_accuracy: 0.9489 - marital_accuracy: 0.9559 - val_loss: 0.5647 - val_income_loss: 0.2180 - val_marital_loss: 0.3467 - val_income_accuracy: 0.9442 - val_marital_accuracy: 0.8621
# ROC-AUC-income-Train: 0.9442 ROC-AUC-income-Validation: 0.9379 ROC-AUC-income-Test: 0.9366
# ROC-AUC-marital-Train: 0.9922 ROC-AUC-marital-Validation: 0.9632 ROC-AUC-marital-Test: 0.9626
# Epoch 38/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2443 - income_loss: 0.1313 - marital_loss: 0.1131 - income_accuracy: 0.9484 - marital_accuracy: 0.9555 - val_loss: 0.4815 - val_income_loss: 0.1890 - val_marital_loss: 0.2925 - val_income_accuracy: 0.9452 - val_marital_accuracy: 0.8848
# ROC-AUC-income-Train: 0.9439 ROC-AUC-income-Validation: 0.9383 ROC-AUC-income-Test: 0.9373
# ROC-AUC-marital-Train: 0.9895 ROC-AUC-marital-Validation: 0.9609 ROC-AUC-marital-Test: 0.9604
# Epoch 39/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2394 - income_loss: 0.1297 - marital_loss: 0.1097 - income_accuracy: 0.9491 - marital_accuracy: 0.9563 - val_loss: 0.4935 - val_income_loss: 0.1983 - val_marital_loss: 0.2952 - val_income_accuracy: 0.9423 - val_marital_accuracy: 0.8828
# ROC-AUC-income-Train: 0.9445 ROC-AUC-income-Validation: 0.938 ROC-AUC-income-Test: 0.9371
# ROC-AUC-marital-Train: 0.9928 ROC-AUC-marital-Validation: 0.9623 ROC-AUC-marital-Test: 0.9618
# Epoch 40/100
# 6236/6236 [==============================] - 19s 3ms/step - loss: 0.2373 - income_loss: 0.1302 - marital_loss: 0.1071 - income_accuracy: 0.9487 - marital_accuracy: 0.9565 - val_loss: 0.5876 - val_income_loss: 0.2207 - val_marital_loss: 0.3669 - val_income_accuracy: 0.9418 - val_marital_accuracy: 0.8558
# ROC-AUC-income-Train: 0.9146 ROC-AUC-income-Validation: 0.904 ROC-AUC-income-Test: 0.9064
# ROC-AUC-marital-Train: 0.9928 ROC-AUC-marital-Validation: 0.9621 ROC-AUC-marital-Test: 0.9615
# Epoch 41/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2352 - income_loss: 0.1295 - marital_loss: 0.1056 - income_accuracy: 0.9499 - marital_accuracy: 0.9565 - val_loss: 0.5079 - val_income_loss: 0.1759 - val_marital_loss: 0.3319 - val_income_accuracy: 0.9443 - val_marital_accuracy: 0.8690
# ROC-AUC-income-Train: 0.9405 ROC-AUC-income-Validation: 0.9326 ROC-AUC-income-Test: 0.9322
# ROC-AUC-marital-Train: 0.9922 ROC-AUC-marital-Validation: 0.9613 ROC-AUC-marital-Test: 0.9607
# Epoch 42/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2371 - income_loss: 0.1311 - marital_loss: 0.1061 - income_accuracy: 0.9484 - marital_accuracy: 0.9564 - val_loss: 0.4988 - val_income_loss: 0.1857 - val_marital_loss: 0.3132 - val_income_accuracy: 0.9458 - val_marital_accuracy: 0.8734
# ROC-AUC-income-Train: 0.9435 ROC-AUC-income-Validation: 0.9383 ROC-AUC-income-Test: 0.9372
# ROC-AUC-marital-Train: 0.9933 ROC-AUC-marital-Validation: 0.9619 ROC-AUC-marital-Test: 0.9611
# Epoch 43/100
# 6236/6236 [==============================] - 17s 3ms/step - loss: 0.2358 - income_loss: 0.1306 - marital_loss: 0.1052 - income_accuracy: 0.9472 - marital_accuracy: 0.9564 - val_loss: 0.5665 - val_income_loss: 0.1897 - val_marital_loss: 0.3768 - val_income_accuracy: 0.9426 - val_marital_accuracy: 0.8543
# ROC-AUC-income-Train: 0.9446 ROC-AUC-income-Validation: 0.9383 ROC-AUC-income-Test: 0.9375
# ROC-AUC-marital-Train: 0.9926 ROC-AUC-marital-Validation: 0.9615 ROC-AUC-marital-Test: 0.961
# Epoch 44/100
# 6236/6236 [==============================] - 17s 3ms/step - loss: 0.2412 - income_loss: 0.1298 - marital_loss: 0.1114 - income_accuracy: 0.9498 - marital_accuracy: 0.9558 - val_loss: 0.5551 - val_income_loss: 0.2329 - val_marital_loss: 0.3222 - val_income_accuracy: 0.9409 - val_marital_accuracy: 0.8739
# ROC-AUC-income-Train: 0.9381 ROC-AUC-income-Validation: 0.9285 ROC-AUC-income-Test: 0.9286
# ROC-AUC-marital-Train: 0.9903 ROC-AUC-marital-Validation: 0.9581 ROC-AUC-marital-Test: 0.9578
# Epoch 45/100
# 6236/6236 [==============================] - 17s 3ms/step - loss: 0.2384 - income_loss: 0.1304 - marital_loss: 0.1080 - income_accuracy: 0.9503 - marital_accuracy: 0.9563 - val_loss: 0.5550 - val_income_loss: 0.1809 - val_marital_loss: 0.3741 - val_income_accuracy: 0.9417 - val_marital_accuracy: 0.8557
# ROC-AUC-income-Train: 0.9382 ROC-AUC-income-Validation: 0.9301 ROC-AUC-income-Test: 0.9309
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.9618 ROC-AUC-marital-Test: 0.9613
# Epoch 46/100
# 6236/6236 [==============================] - 17s 3ms/step - loss: 0.2347 - income_loss: 0.1289 - marital_loss: 0.1059 - income_accuracy: 0.9490 - marital_accuracy: 0.9566 - val_loss: 0.5223 - val_income_loss: 0.1806 - val_marital_loss: 0.3417 - val_income_accuracy: 0.9424 - val_marital_accuracy: 0.8679
# ROC-AUC-income-Train: 0.9458 ROC-AUC-income-Validation: 0.9375 ROC-AUC-income-Test: 0.9377
# ROC-AUC-marital-Train: 0.9908 ROC-AUC-marital-Validation: 0.958 ROC-AUC-marital-Test: 0.9573
# Epoch 47/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2344 - income_loss: 0.1288 - marital_loss: 0.1056 - income_accuracy: 0.9493 - marital_accuracy: 0.9562 - val_loss: 0.4851 - val_income_loss: 0.1735 - val_marital_loss: 0.3115 - val_income_accuracy: 0.9432 - val_marital_accuracy: 0.8774
# ROC-AUC-income-Train: 0.9408 ROC-AUC-income-Validation: 0.9337 ROC-AUC-income-Test: 0.9341
# ROC-AUC-marital-Train: 0.9922 ROC-AUC-marital-Validation: 0.9595 ROC-AUC-marital-Test: 0.959
# Epoch 48/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2343 - income_loss: 0.1293 - marital_loss: 0.1049 - income_accuracy: 0.9497 - marital_accuracy: 0.9569 - val_loss: 0.5841 - val_income_loss: 0.1793 - val_marital_loss: 0.4048 - val_income_accuracy: 0.9458 - val_marital_accuracy: 0.8437
# ROC-AUC-income-Train: 0.9439 ROC-AUC-income-Validation: 0.9371 ROC-AUC-income-Test: 0.9371
# ROC-AUC-marital-Train: 0.9929 ROC-AUC-marital-Validation: 0.9591 ROC-AUC-marital-Test: 0.9585
# Epoch 49/100
# 6236/6236 [==============================] - 17s 3ms/step - loss: 0.2334 - income_loss: 0.1293 - marital_loss: 0.1040 - income_accuracy: 0.9483 - marital_accuracy: 0.9569 - val_loss: 0.6582 - val_income_loss: 0.2546 - val_marital_loss: 0.4036 - val_income_accuracy: 0.9428 - val_marital_accuracy: 0.8432
# ROC-AUC-income-Train: 0.9125 ROC-AUC-income-Validation: 0.9026 ROC-AUC-income-Test: 0.9058
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.9582 ROC-AUC-marital-Test: 0.9576
# Epoch 50/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2363 - income_loss: 0.1309 - marital_loss: 0.1053 - income_accuracy: 0.9481 - marital_accuracy: 0.9570 - val_loss: 0.5425 - val_income_loss: 0.1889 - val_marital_loss: 0.3536 - val_income_accuracy: 0.9448 - val_marital_accuracy: 0.8652
# ROC-AUC-income-Train: 0.9422 ROC-AUC-income-Validation: 0.9353 ROC-AUC-income-Test: 0.9351
# ROC-AUC-marital-Train: 0.9896 ROC-AUC-marital-Validation: 0.9564 ROC-AUC-marital-Test: 0.9561
# Epoch 51/100
# 6236/6236 [==============================] - 19s 3ms/step - loss: 0.2344 - income_loss: 0.1293 - marital_loss: 0.1051 - income_accuracy: 0.9498 - marital_accuracy: 0.9565 - val_loss: 0.5375 - val_income_loss: 0.1994 - val_marital_loss: 0.3381 - val_income_accuracy: 0.9436 - val_marital_accuracy: 0.8676
# ROC-AUC-income-Train: 0.9452 ROC-AUC-income-Validation: 0.939 ROC-AUC-income-Test: 0.9388
# ROC-AUC-marital-Train: 0.9927 ROC-AUC-marital-Validation: 0.9586 ROC-AUC-marital-Test: 0.958
# Epoch 52/100
# 6236/6236 [==============================] - 19s 3ms/step - loss: 0.2324 - income_loss: 0.1287 - marital_loss: 0.1037 - income_accuracy: 0.9494 - marital_accuracy: 0.9568 - val_loss: 0.5244 - val_income_loss: 0.1737 - val_marital_loss: 0.3506 - val_income_accuracy: 0.9458 - val_marital_accuracy: 0.8639
# ROC-AUC-income-Train: 0.9437 ROC-AUC-income-Validation: 0.9382 ROC-AUC-income-Test: 0.9378
# ROC-AUC-marital-Train: 0.9936 ROC-AUC-marital-Validation: 0.9584 ROC-AUC-marital-Test: 0.9577
# Epoch 53/100
# 6236/6236 [==============================] - 19s 3ms/step - loss: 0.2320 - income_loss: 0.1281 - marital_loss: 0.1039 - income_accuracy: 0.9500 - marital_accuracy: 0.9568 - val_loss: 0.5366 - val_income_loss: 0.1836 - val_marital_loss: 0.3530 - val_income_accuracy: 0.9418 - val_marital_accuracy: 0.8606
# ROC-AUC-income-Train: 0.9456 ROC-AUC-income-Validation: 0.9373 ROC-AUC-income-Test: 0.9385
# ROC-AUC-marital-Train: 0.9935 ROC-AUC-marital-Validation: 0.9575 ROC-AUC-marital-Test: 0.9569
# Epoch 54/100
# 6236/6236 [==============================] - 19s 3ms/step - loss: 0.2316 - income_loss: 0.1279 - marital_loss: 0.1036 - income_accuracy: 0.9498 - marital_accuracy: 0.9570 - val_loss: 0.5650 - val_income_loss: 0.1910 - val_marital_loss: 0.3740 - val_income_accuracy: 0.9434 - val_marital_accuracy: 0.8565
# ROC-AUC-income-Train: 0.9446 ROC-AUC-income-Validation: 0.9376 ROC-AUC-income-Test: 0.9378
# ROC-AUC-marital-Train: 0.9924 ROC-AUC-marital-Validation: 0.9562 ROC-AUC-marital-Test: 0.9555
# Epoch 55/100
# 6236/6236 [==============================] - 19s 3ms/step - loss: 0.2342 - income_loss: 0.1304 - marital_loss: 0.1038 - income_accuracy: 0.9490 - marital_accuracy: 0.9567 - val_loss: 0.5398 - val_income_loss: 0.1913 - val_marital_loss: 0.3485 - val_income_accuracy: 0.9417 - val_marital_accuracy: 0.8639
# ROC-AUC-income-Train: 0.9434 ROC-AUC-income-Validation: 0.9348 ROC-AUC-income-Test: 0.9355
# ROC-AUC-marital-Train: 0.9931 ROC-AUC-marital-Validation: 0.9565 ROC-AUC-marital-Test: 0.9558
# Epoch 56/100
# 6236/6236 [==============================] - 19s 3ms/step - loss: 0.2320 - income_loss: 0.1294 - marital_loss: 0.1025 - income_accuracy: 0.9486 - marital_accuracy: 0.9575 - val_loss: 0.6017 - val_income_loss: 0.1703 - val_marital_loss: 0.4314 - val_income_accuracy: 0.9447 - val_marital_accuracy: 0.8375
# ROC-AUC-income-Train: 0.9438 ROC-AUC-income-Validation: 0.9375 ROC-AUC-income-Test: 0.9375
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9571 ROC-AUC-marital-Test: 0.9563
# Epoch 57/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2306 - income_loss: 0.1272 - marital_loss: 0.1034 - income_accuracy: 0.9508 - marital_accuracy: 0.9568 - val_loss: 0.6227 - val_income_loss: 0.2006 - val_marital_loss: 0.4221 - val_income_accuracy: 0.9448 - val_marital_accuracy: 0.8408
# ROC-AUC-income-Train: 0.9451 ROC-AUC-income-Validation: 0.9376 ROC-AUC-income-Test: 0.9379
# ROC-AUC-marital-Train: 0.9935 ROC-AUC-marital-Validation: 0.9564 ROC-AUC-marital-Test: 0.9558
# Epoch 58/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2321 - income_loss: 0.1294 - marital_loss: 0.1026 - income_accuracy: 0.9500 - marital_accuracy: 0.9572 - val_loss: 0.5492 - val_income_loss: 0.2093 - val_marital_loss: 0.3399 - val_income_accuracy: 0.9428 - val_marital_accuracy: 0.8671
# ROC-AUC-income-Train: 0.9445 ROC-AUC-income-Validation: 0.9368 ROC-AUC-income-Test: 0.9365
# ROC-AUC-marital-Train: 0.9943 ROC-AUC-marital-Validation: 0.9564 ROC-AUC-marital-Test: 0.9558
# Epoch 59/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2323 - income_loss: 0.1288 - marital_loss: 0.1036 - income_accuracy: 0.9497 - marital_accuracy: 0.9568 - val_loss: 0.5845 - val_income_loss: 0.1842 - val_marital_loss: 0.4003 - val_income_accuracy: 0.9450 - val_marital_accuracy: 0.8490
# ROC-AUC-income-Train: 0.9425 ROC-AUC-income-Validation: 0.9357 ROC-AUC-income-Test: 0.9363
# ROC-AUC-marital-Train: 0.9934 ROC-AUC-marital-Validation: 0.9563 ROC-AUC-marital-Test: 0.9557
# Epoch 60/100
# 6236/6236 [==============================] - 17s 3ms/step - loss: 0.2348 - income_loss: 0.1327 - marital_loss: 0.1021 - income_accuracy: 0.9503 - marital_accuracy: 0.9573 - val_loss: 0.5919 - val_income_loss: 0.1845 - val_marital_loss: 0.4073 - val_income_accuracy: 0.9389 - val_marital_accuracy: 0.8458
# ROC-AUC-income-Train: 0.9101 ROC-AUC-income-Validation: 0.8888 ROC-AUC-income-Test: 0.8822
# ROC-AUC-marital-Train: 0.9936 ROC-AUC-marital-Validation: 0.9558 ROC-AUC-marital-Test: 0.955
# Epoch 61/100
# 6236/6236 [==============================] - 17s 3ms/step - loss: 0.2305 - income_loss: 0.1277 - marital_loss: 0.1029 - income_accuracy: 0.9498 - marital_accuracy: 0.9568 - val_loss: 0.5899 - val_income_loss: 0.1777 - val_marital_loss: 0.4121 - val_income_accuracy: 0.9439 - val_marital_accuracy: 0.8432
# ROC-AUC-income-Train: 0.9443 ROC-AUC-income-Validation: 0.9376 ROC-AUC-income-Test: 0.9378
# ROC-AUC-marital-Train: 0.992 ROC-AUC-marital-Validation: 0.9538 ROC-AUC-marital-Test: 0.953
# Epoch 62/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2342 - income_loss: 0.1317 - marital_loss: 0.1026 - income_accuracy: 0.9482 - marital_accuracy: 0.9569 - val_loss: 0.5535 - val_income_loss: 0.1764 - val_marital_loss: 0.3771 - val_income_accuracy: 0.9440 - val_marital_accuracy: 0.8576
# ROC-AUC-income-Train: 0.9453 ROC-AUC-income-Validation: 0.9356 ROC-AUC-income-Test: 0.9362
# ROC-AUC-marital-Train: 0.9925 ROC-AUC-marital-Validation: 0.9543 ROC-AUC-marital-Test: 0.9537
# Epoch 63/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2318 - income_loss: 0.1291 - marital_loss: 0.1027 - income_accuracy: 0.9488 - marital_accuracy: 0.9571 - val_loss: 0.8355 - val_income_loss: 0.3980 - val_marital_loss: 0.4375 - val_income_accuracy: 0.9384 - val_marital_accuracy: 0.8293
# ROC-AUC-income-Train: 0.8353 ROC-AUC-income-Validation: 0.8241 ROC-AUC-income-Test: 0.8281
# ROC-AUC-marital-Train: 0.9943 ROC-AUC-marital-Validation: 0.9546 ROC-AUC-marital-Test: 0.954
# Epoch 64/100
# 6236/6236 [==============================] - 19s 3ms/step - loss: 0.2310 - income_loss: 0.1291 - marital_loss: 0.1019 - income_accuracy: 0.9503 - marital_accuracy: 0.9572 - val_loss: 0.5764 - val_income_loss: 0.2020 - val_marital_loss: 0.3744 - val_income_accuracy: 0.9443 - val_marital_accuracy: 0.8590
# ROC-AUC-income-Train: 0.9445 ROC-AUC-income-Validation: 0.9369 ROC-AUC-income-Test: 0.9368
# ROC-AUC-marital-Train: 0.9923 ROC-AUC-marital-Validation: 0.9532 ROC-AUC-marital-Test: 0.9525
# Epoch 65/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2298 - income_loss: 0.1283 - marital_loss: 0.1014 - income_accuracy: 0.9510 - marital_accuracy: 0.9573 - val_loss: 0.6162 - val_income_loss: 0.1772 - val_marital_loss: 0.4390 - val_income_accuracy: 0.9396 - val_marital_accuracy: 0.8377
# ROC-AUC-income-Train: 0.9378 ROC-AUC-income-Validation: 0.925 ROC-AUC-income-Test: 0.9229
# ROC-AUC-marital-Train: 0.9938 ROC-AUC-marital-Validation: 0.9534 ROC-AUC-marital-Test: 0.9528
# Epoch 66/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2322 - income_loss: 0.1284 - marital_loss: 0.1037 - income_accuracy: 0.9504 - marital_accuracy: 0.9573 - val_loss: 0.6180 - val_income_loss: 0.2057 - val_marital_loss: 0.4123 - val_income_accuracy: 0.9425 - val_marital_accuracy: 0.8405
# ROC-AUC-income-Train: 0.9408 ROC-AUC-income-Validation: 0.9349 ROC-AUC-income-Test: 0.9351
# ROC-AUC-marital-Train: 0.9936 ROC-AUC-marital-Validation: 0.9532 ROC-AUC-marital-Test: 0.9524
# Epoch 67/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2283 - income_loss: 0.1264 - marital_loss: 0.1019 - income_accuracy: 0.9509 - marital_accuracy: 0.9571 - val_loss: 0.6591 - val_income_loss: 0.1728 - val_marital_loss: 0.4862 - val_income_accuracy: 0.9455 - val_marital_accuracy: 0.8200
# ROC-AUC-income-Train: 0.9448 ROC-AUC-income-Validation: 0.9359 ROC-AUC-income-Test: 0.9366
# ROC-AUC-marital-Train: 0.9924 ROC-AUC-marital-Validation: 0.9519 ROC-AUC-marital-Test: 0.9512
# Epoch 68/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2298 - income_loss: 0.1278 - marital_loss: 0.1020 - income_accuracy: 0.9507 - marital_accuracy: 0.9573 - val_loss: 0.6100 - val_income_loss: 0.1730 - val_marital_loss: 0.4371 - val_income_accuracy: 0.9434 - val_marital_accuracy: 0.8343
# ROC-AUC-income-Train: 0.9429 ROC-AUC-income-Validation: 0.9358 ROC-AUC-income-Test: 0.9373
# ROC-AUC-marital-Train: 0.9938 ROC-AUC-marital-Validation: 0.9514 ROC-AUC-marital-Test: 0.9507
# Epoch 69/100
# 6236/6236 [==============================] - 19s 3ms/step - loss: 0.2324 - income_loss: 0.1291 - marital_loss: 0.1033 - income_accuracy: 0.9494 - marital_accuracy: 0.9574 - val_loss: 0.6294 - val_income_loss: 0.1890 - val_marital_loss: 0.4404 - val_income_accuracy: 0.9441 - val_marital_accuracy: 0.8389
# ROC-AUC-income-Train: 0.9396 ROC-AUC-income-Validation: 0.9327 ROC-AUC-income-Test: 0.933
# ROC-AUC-marital-Train: 0.9917 ROC-AUC-marital-Validation: 0.9518 ROC-AUC-marital-Test: 0.9511
# Epoch 70/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2277 - income_loss: 0.1260 - marital_loss: 0.1017 - income_accuracy: 0.9512 - marital_accuracy: 0.9575 - val_loss: 0.5858 - val_income_loss: 0.1861 - val_marital_loss: 0.3997 - val_income_accuracy: 0.9426 - val_marital_accuracy: 0.8483
# ROC-AUC-income-Train: 0.9409 ROC-AUC-income-Validation: 0.933 ROC-AUC-income-Test: 0.9329
# ROC-AUC-marital-Train: 0.9932 ROC-AUC-marital-Validation: 0.952 ROC-AUC-marital-Test: 0.9512
# Epoch 71/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2321 - income_loss: 0.1300 - marital_loss: 0.1021 - income_accuracy: 0.9478 - marital_accuracy: 0.9573 - val_loss: 0.5792 - val_income_loss: 0.1948 - val_marital_loss: 0.3843 - val_income_accuracy: 0.9419 - val_marital_accuracy: 0.8521
# ROC-AUC-income-Train: 0.9276 ROC-AUC-income-Validation: 0.9143 ROC-AUC-income-Test: 0.9158
# ROC-AUC-marital-Train: 0.9938 ROC-AUC-marital-Validation: 0.9521 ROC-AUC-marital-Test: 0.9513
# Epoch 72/100
# 6236/6236 [==============================] - 19s 3ms/step - loss: 0.2288 - income_loss: 0.1280 - marital_loss: 0.1008 - income_accuracy: 0.9496 - marital_accuracy: 0.9572 - val_loss: 0.6808 - val_income_loss: 0.1908 - val_marital_loss: 0.4900 - val_income_accuracy: 0.9459 - val_marital_accuracy: 0.8230
# ROC-AUC-income-Train: 0.9435 ROC-AUC-income-Validation: 0.9361 ROC-AUC-income-Test: 0.9362
# ROC-AUC-marital-Train: 0.9934 ROC-AUC-marital-Validation: 0.9504 ROC-AUC-marital-Test: 0.9497
# Epoch 73/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2344 - income_loss: 0.1332 - marital_loss: 0.1012 - income_accuracy: 0.9449 - marital_accuracy: 0.9573 - val_loss: 0.6710 - val_income_loss: 0.1974 - val_marital_loss: 0.4736 - val_income_accuracy: 0.9276 - val_marital_accuracy: 0.8321
# ROC-AUC-income-Train: 0.9325 ROC-AUC-income-Validation: 0.9218 ROC-AUC-income-Test: 0.9222
# ROC-AUC-marital-Train: 0.993 ROC-AUC-marital-Validation: 0.9511 ROC-AUC-marital-Test: 0.9502
# Epoch 74/100
# 6236/6236 [==============================] - 19s 3ms/step - loss: 0.2323 - income_loss: 0.1314 - marital_loss: 0.1009 - income_accuracy: 0.9479 - marital_accuracy: 0.9576 - val_loss: 0.6317 - val_income_loss: 0.2089 - val_marital_loss: 0.4228 - val_income_accuracy: 0.9262 - val_marital_accuracy: 0.8418
# ROC-AUC-income-Train: 0.8854 ROC-AUC-income-Validation: 0.8625 ROC-AUC-income-Test: 0.8695
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.9507 ROC-AUC-marital-Test: 0.95
# Epoch 75/100
# 6236/6236 [==============================] - 19s 3ms/step - loss: 0.2326 - income_loss: 0.1311 - marital_loss: 0.1015 - income_accuracy: 0.9492 - marital_accuracy: 0.9573 - val_loss: 0.5891 - val_income_loss: 0.1939 - val_marital_loss: 0.3953 - val_income_accuracy: 0.9450 - val_marital_accuracy: 0.8507
# ROC-AUC-income-Train: 0.9433 ROC-AUC-income-Validation: 0.9352 ROC-AUC-income-Test: 0.9348
# ROC-AUC-marital-Train: 0.9924 ROC-AUC-marital-Validation: 0.9499 ROC-AUC-marital-Test: 0.949
# Epoch 76/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2291 - income_loss: 0.1269 - marital_loss: 0.1022 - income_accuracy: 0.9511 - marital_accuracy: 0.9572 - val_loss: 0.5994 - val_income_loss: 0.1982 - val_marital_loss: 0.4012 - val_income_accuracy: 0.9428 - val_marital_accuracy: 0.8478
# ROC-AUC-income-Train: 0.9393 ROC-AUC-income-Validation: 0.9325 ROC-AUC-income-Test: 0.9317
# ROC-AUC-marital-Train: 0.993 ROC-AUC-marital-Validation: 0.9499 ROC-AUC-marital-Test: 0.9491
# Epoch 77/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2290 - income_loss: 0.1280 - marital_loss: 0.1010 - income_accuracy: 0.9508 - marital_accuracy: 0.9572 - val_loss: 0.6324 - val_income_loss: 0.2132 - val_marital_loss: 0.4192 - val_income_accuracy: 0.9434 - val_marital_accuracy: 0.8422
# ROC-AUC-income-Train: 0.9419 ROC-AUC-income-Validation: 0.9335 ROC-AUC-income-Test: 0.9342
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9502 ROC-AUC-marital-Test: 0.9493
# Epoch 78/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2325 - income_loss: 0.1326 - marital_loss: 0.0999 - income_accuracy: 0.9453 - marital_accuracy: 0.9575 - val_loss: 0.6134 - val_income_loss: 0.2156 - val_marital_loss: 0.3979 - val_income_accuracy: 0.9382 - val_marital_accuracy: 0.8495
# ROC-AUC-income-Train: 0.9347 ROC-AUC-income-Validation: 0.9233 ROC-AUC-income-Test: 0.9232
# ROC-AUC-marital-Train: 0.9931 ROC-AUC-marital-Validation: 0.9485 ROC-AUC-marital-Test: 0.9477
# Epoch 79/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2289 - income_loss: 0.1287 - marital_loss: 0.1002 - income_accuracy: 0.9497 - marital_accuracy: 0.9578 - val_loss: 0.6596 - val_income_loss: 0.2259 - val_marital_loss: 0.4337 - val_income_accuracy: 0.9404 - val_marital_accuracy: 0.8371
# ROC-AUC-income-Train: 0.9459 ROC-AUC-income-Validation: 0.9352 ROC-AUC-income-Test: 0.9335
# ROC-AUC-marital-Train: 0.9943 ROC-AUC-marital-Validation: 0.9496 ROC-AUC-marital-Test: 0.9487
# Epoch 80/100
# 6236/6236 [==============================] - 21s 3ms/step - loss: 0.2262 - income_loss: 0.1262 - marital_loss: 0.1000 - income_accuracy: 0.9502 - marital_accuracy: 0.9574 - val_loss: 0.7869 - val_income_loss: 0.2039 - val_marital_loss: 0.5831 - val_income_accuracy: 0.9457 - val_marital_accuracy: 0.8045
# ROC-AUC-income-Train: 0.9447 ROC-AUC-income-Validation: 0.9367 ROC-AUC-income-Test: 0.9361
# ROC-AUC-marital-Train: 0.9923 ROC-AUC-marital-Validation: 0.9423 ROC-AUC-marital-Test: 0.9418
# Epoch 81/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2287 - income_loss: 0.1273 - marital_loss: 0.1015 - income_accuracy: 0.9505 - marital_accuracy: 0.9578 - val_loss: 0.7287 - val_income_loss: 0.1932 - val_marital_loss: 0.5355 - val_income_accuracy: 0.9419 - val_marital_accuracy: 0.8114
# ROC-AUC-income-Train: 0.9453 ROC-AUC-income-Validation: 0.9376 ROC-AUC-income-Test: 0.9367
# ROC-AUC-marital-Train: 0.9934 ROC-AUC-marital-Validation: 0.9489 ROC-AUC-marital-Test: 0.948
# Epoch 82/100
# 6236/6236 [==============================] - 19s 3ms/step - loss: 0.2266 - income_loss: 0.1253 - marital_loss: 0.1013 - income_accuracy: 0.9517 - marital_accuracy: 0.9575 - val_loss: 0.5856 - val_income_loss: 0.1850 - val_marital_loss: 0.4006 - val_income_accuracy: 0.9441 - val_marital_accuracy: 0.8485
# ROC-AUC-income-Train: 0.944 ROC-AUC-income-Validation: 0.9359 ROC-AUC-income-Test: 0.9358
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.9486 ROC-AUC-marital-Test: 0.9477
# Epoch 83/100
# 6236/6236 [==============================] - 19s 3ms/step - loss: 0.2272 - income_loss: 0.1269 - marital_loss: 0.1003 - income_accuracy: 0.9509 - marital_accuracy: 0.9579 - val_loss: 0.6491 - val_income_loss: 0.2247 - val_marital_loss: 0.4244 - val_income_accuracy: 0.9408 - val_marital_accuracy: 0.8365
# ROC-AUC-income-Train: 0.9457 ROC-AUC-income-Validation: 0.9364 ROC-AUC-income-Test: 0.9357
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.9486 ROC-AUC-marital-Test: 0.9477
# Epoch 84/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2298 - income_loss: 0.1299 - marital_loss: 0.0999 - income_accuracy: 0.9477 - marital_accuracy: 0.9577 - val_loss: 0.6654 - val_income_loss: 0.1903 - val_marital_loss: 0.4750 - val_income_accuracy: 0.9459 - val_marital_accuracy: 0.8295
# ROC-AUC-income-Train: 0.9429 ROC-AUC-income-Validation: 0.9335 ROC-AUC-income-Test: 0.9332
# ROC-AUC-marital-Train: 0.9937 ROC-AUC-marital-Validation: 0.9472 ROC-AUC-marital-Test: 0.9464
# Epoch 85/100
# 6236/6236 [==============================] - 19s 3ms/step - loss: 0.2259 - income_loss: 0.1266 - marital_loss: 0.0992 - income_accuracy: 0.9509 - marital_accuracy: 0.9578 - val_loss: 0.6922 - val_income_loss: 0.2437 - val_marital_loss: 0.4485 - val_income_accuracy: 0.9411 - val_marital_accuracy: 0.8325
# ROC-AUC-income-Train: 0.9441 ROC-AUC-income-Validation: 0.9338 ROC-AUC-income-Test: 0.9336
# ROC-AUC-marital-Train: 0.993 ROC-AUC-marital-Validation: 0.9467 ROC-AUC-marital-Test: 0.9458
# Epoch 86/100
# 6236/6236 [==============================] - 19s 3ms/step - loss: 0.2255 - income_loss: 0.1263 - marital_loss: 0.0992 - income_accuracy: 0.9517 - marital_accuracy: 0.9578 - val_loss: 0.6649 - val_income_loss: 0.2234 - val_marital_loss: 0.4415 - val_income_accuracy: 0.9443 - val_marital_accuracy: 0.8385
# ROC-AUC-income-Train: 0.9448 ROC-AUC-income-Validation: 0.9354 ROC-AUC-income-Test: 0.9347
# ROC-AUC-marital-Train: 0.9937 ROC-AUC-marital-Validation: 0.9471 ROC-AUC-marital-Test: 0.9462
# Epoch 87/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2251 - income_loss: 0.1251 - marital_loss: 0.1000 - income_accuracy: 0.9519 - marital_accuracy: 0.9574 - val_loss: 0.7008 - val_income_loss: 0.2178 - val_marital_loss: 0.4830 - val_income_accuracy: 0.9455 - val_marital_accuracy: 0.8267
# ROC-AUC-income-Train: 0.945 ROC-AUC-income-Validation: 0.9365 ROC-AUC-income-Test: 0.936
# ROC-AUC-marital-Train: 0.9929 ROC-AUC-marital-Validation: 0.9439 ROC-AUC-marital-Test: 0.9431
# Epoch 88/100
# 6236/6236 [==============================] - 19s 3ms/step - loss: 0.2254 - income_loss: 0.1254 - marital_loss: 0.1000 - income_accuracy: 0.9517 - marital_accuracy: 0.9575 - val_loss: 0.6996 - val_income_loss: 0.2105 - val_marital_loss: 0.4891 - val_income_accuracy: 0.9415 - val_marital_accuracy: 0.8214
# ROC-AUC-income-Train: 0.945 ROC-AUC-income-Validation: 0.9364 ROC-AUC-income-Test: 0.9363
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.9468 ROC-AUC-marital-Test: 0.9458
# Epoch 89/100
# 6236/6236 [==============================] - 19s 3ms/step - loss: 0.2253 - income_loss: 0.1251 - marital_loss: 0.1001 - income_accuracy: 0.9518 - marital_accuracy: 0.9577 - val_loss: 0.6824 - val_income_loss: 0.2029 - val_marital_loss: 0.4795 - val_income_accuracy: 0.9420 - val_marital_accuracy: 0.8285
# ROC-AUC-income-Train: 0.9445 ROC-AUC-income-Validation: 0.934 ROC-AUC-income-Test: 0.9346
# ROC-AUC-marital-Train: 0.9938 ROC-AUC-marital-Validation: 0.9467 ROC-AUC-marital-Test: 0.9458
# Epoch 90/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2248 - income_loss: 0.1251 - marital_loss: 0.0997 - income_accuracy: 0.9517 - marital_accuracy: 0.9577 - val_loss: 0.6200 - val_income_loss: 0.1989 - val_marital_loss: 0.4211 - val_income_accuracy: 0.9451 - val_marital_accuracy: 0.8411
# ROC-AUC-income-Train: 0.9457 ROC-AUC-income-Validation: 0.9367 ROC-AUC-income-Test: 0.9363
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.9463 ROC-AUC-marital-Test: 0.9454
# Epoch 91/100
# 6236/6236 [==============================] - 19s 3ms/step - loss: 0.2260 - income_loss: 0.1270 - marital_loss: 0.0990 - income_accuracy: 0.9492 - marital_accuracy: 0.9575 - val_loss: 0.6176 - val_income_loss: 0.2092 - val_marital_loss: 0.4084 - val_income_accuracy: 0.9409 - val_marital_accuracy: 0.8471
# ROC-AUC-income-Train: 0.9447 ROC-AUC-income-Validation: 0.9347 ROC-AUC-income-Test: 0.935
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9466 ROC-AUC-marital-Test: 0.9456
# Epoch 92/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2247 - income_loss: 0.1256 - marital_loss: 0.0990 - income_accuracy: 0.9513 - marital_accuracy: 0.9580 - val_loss: 0.6196 - val_income_loss: 0.2097 - val_marital_loss: 0.4099 - val_income_accuracy: 0.9457 - val_marital_accuracy: 0.8456
# ROC-AUC-income-Train: 0.9444 ROC-AUC-income-Validation: 0.9353 ROC-AUC-income-Test: 0.9347
# ROC-AUC-marital-Train: 0.9944 ROC-AUC-marital-Validation: 0.9452 ROC-AUC-marital-Test: 0.9443
# Epoch 93/100
# 6236/6236 [==============================] - 18s 3ms/step - loss: 0.2263 - income_loss: 0.1266 - marital_loss: 0.0997 - income_accuracy: 0.9504 - marital_accuracy: 0.9575 - val_loss: 0.7040 - val_income_loss: 0.2280 - val_marital_loss: 0.4760 - val_income_accuracy: 0.9402 - val_marital_accuracy: 0.8230
# ROC-AUC-income-Train: 0.9454 ROC-AUC-income-Validation: 0.9354 ROC-AUC-income-Test: 0.9359
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9459 ROC-AUC-marital-Test: 0.9447
# Epoch 94/100
# 6236/6236 [==============================] - 20s 3ms/step - loss: 0.2252 - income_loss: 0.1254 - marital_loss: 0.0998 - income_accuracy: 0.9514 - marital_accuracy: 0.9574 - val_loss: 0.6724 - val_income_loss: 0.2045 - val_marital_loss: 0.4679 - val_income_accuracy: 0.9456 - val_marital_accuracy: 0.8317
# ROC-AUC-income-Train: 0.9446 ROC-AUC-income-Validation: 0.9352 ROC-AUC-income-Test: 0.9349
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.945 ROC-AUC-marital-Test: 0.944
# Epoch 95/100
# 6236/6236 [==============================] - 20s 3ms/step - loss: 0.2251 - income_loss: 0.1254 - marital_loss: 0.0997 - income_accuracy: 0.9514 - marital_accuracy: 0.9577 - val_loss: 0.5946 - val_income_loss: 0.2273 - val_marital_loss: 0.3674 - val_income_accuracy: 0.9440 - val_marital_accuracy: 0.8624
# ROC-AUC-income-Train: 0.9458 ROC-AUC-income-Validation: 0.9364 ROC-AUC-income-Test: 0.9361
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.9452 ROC-AUC-marital-Test: 0.9443
# Epoch 96/100
# 6236/6236 [==============================] - 20s 3ms/step - loss: 0.2284 - income_loss: 0.1296 - marital_loss: 0.0988 - income_accuracy: 0.9508 - marital_accuracy: 0.9578 - val_loss: 0.6364 - val_income_loss: 0.2127 - val_marital_loss: 0.4237 - val_income_accuracy: 0.9430 - val_marital_accuracy: 0.8439
# ROC-AUC-income-Train: 0.9457 ROC-AUC-income-Validation: 0.9362 ROC-AUC-income-Test: 0.9367
# ROC-AUC-marital-Train: 0.9934 ROC-AUC-marital-Validation: 0.9449 ROC-AUC-marital-Test: 0.9439
# Epoch 97/100
# 6236/6236 [==============================] - 19s 3ms/step - loss: 0.2261 - income_loss: 0.1275 - marital_loss: 0.0986 - income_accuracy: 0.9493 - marital_accuracy: 0.9579 - val_loss: 0.7040 - val_income_loss: 0.2193 - val_marital_loss: 0.4847 - val_income_accuracy: 0.9428 - val_marital_accuracy: 0.8235
# ROC-AUC-income-Train: 0.9459 ROC-AUC-income-Validation: 0.9359 ROC-AUC-income-Test: 0.9361
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.9455 ROC-AUC-marital-Test: 0.9444
# Epoch 98/100
# 6236/6236 [==============================] - 19s 3ms/step - loss: 0.2255 - income_loss: 0.1266 - marital_loss: 0.0989 - income_accuracy: 0.9502 - marital_accuracy: 0.9580 - val_loss: 0.5949 - val_income_loss: 0.1990 - val_marital_loss: 0.3959 - val_income_accuracy: 0.9442 - val_marital_accuracy: 0.8502
# ROC-AUC-income-Train: 0.9457 ROC-AUC-income-Validation: 0.9372 ROC-AUC-income-Test: 0.9374
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9448 ROC-AUC-marital-Test: 0.9437
# Epoch 99/100
# 6236/6236 [==============================] - 19s 3ms/step - loss: 0.2252 - income_loss: 0.1265 - marital_loss: 0.0987 - income_accuracy: 0.9501 - marital_accuracy: 0.9578 - val_loss: 0.7463 - val_income_loss: 0.2327 - val_marital_loss: 0.5136 - val_income_accuracy: 0.9415 - val_marital_accuracy: 0.8142
# ROC-AUC-income-Train: 0.9452 ROC-AUC-income-Validation: 0.9351 ROC-AUC-income-Test: 0.9356
# ROC-AUC-marital-Train: 0.9944 ROC-AUC-marital-Validation: 0.9444 ROC-AUC-marital-Test: 0.9434
# Epoch 100/100
# 6236/6236 [==============================] - 19s 3ms/step - loss: 0.2250 - income_loss: 0.1264 - marital_loss: 0.0986 - income_accuracy: 0.9516 - marital_accuracy: 0.9579 - val_loss: 0.6324 - val_income_loss: 0.2094 - val_marital_loss: 0.4230 - val_income_accuracy: 0.9434 - val_marital_accuracy: 0.8465
# ROC-AUC-income-Train: 0.9465 ROC-AUC-income-Validation: 0.934 ROC-AUC-income-Test: 0.9352
# ROC-AUC-marital-Train: 0.9928 ROC-AUC-marital-Validation: 0.9437 ROC-AUC-marital-Test: 0.9426
